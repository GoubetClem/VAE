# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <hr> <center> <font size="+3.5"> <b> Interpréter des conditions atypiques à l'aide d'autoencodeurs variationnels conditionnels: différentes méthodes de calculer les loss avec Tensorflow. </b> </font> </center> <hr>
# </div>

# %% [markdown]
# <div class="alert alert-block" role="alert">
#     <center><b> <u>Auteur :</u>  Lorenzo HERMEZ </b></center>
# </div>
# </div>

# %% [markdown]
# # Table de contenu
#
# ## 0. Préparation de l'environnement de travail
# - chargement des modules
# - mise en forme des données
# - définition de quelques fonctions utiles
#
# ## 1. Premier modèle VAE
# - construction du modèle
# - entrainement
# - évaluation de la représentation obtenue
# - premières interprétations
#
# ## 2. Modèle CVAE
# - construction du modèle
# - entrainement
# - évaluation de la représentation obtenue
# - premières interprétations
# - analyse spécifique jours fériés et points atypiques

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     <font size="+2"> <b> 0. Preparation de l'environnement de travail </b> </font> <hr>
# </div>

# %% [markdown]
# # Chargement des modules et mise en forme des données

# %%
#import external libraries
import sys
import os
import datetime
import pandas as pd
import numpy as np
import pickle
from matplotlib import pyplot as plt
import seaborn as sn
from scipy import stats
import cv2 #from open-cv, to convert array to images
from IPython.display import Image
from tensorflow.keras.callbacks import TensorBoard
from time import time
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2022-06-14 08:25:39.937827: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-14 08:25:39.937853: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#root git folder 
name_model="vae_test"
path_second_folder = %pwd #"/home/goubetcle/Documents/Git/VAE/"
save_path = os.path.join(path_second_folder,"Results")#"/home/goubetcle/Documents/VAE/"
log_dir_model=os.path.join(save_path,"logs")
#path_main_folder = '/home/jovyan'#specify the root folder of the git repo

#add  to path root git folder 
sys.path.append(path_second_folder)

# %%
import importlib

sys.path.append(path_second_folder+'/src')

#import models, loss_class, params_class,AE_blocks,metrics
from src.models import *
#importlib.reload(models)
from src.loss_class import *
#importlib.reload(loss_class)
from src.params_class import *
#importlib.reload(params_class)
import src.AE_blocks
#importlib.reload(AE_blocks)
from src.metrics import *
#importlib.reload(metrics)
from src.utils import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Les données de consommation et de température sont des prises de mesure par pas de temps 30 minutes pendant 5 années de décembre 2012 à décembre 2020.

# %%
# Load dataframe
dataset_csv = os.path.join('data', "dataset_2012_2020.csv")
df_data = pd.read_csv(dataset_csv, sep=";",)
df_data.utc_datetime = pd.to_datetime(df_data.utc_datetime, utc=True)

#Visualize data frame head
df_data.tail(5)
# Out:
#                     utc_datetime  Consommation  prevision_j  prevision_j-1  \
# 157819 2020-12-31 21:30:00+00:00       64423.0      63700.0        64400.0
# 157820 2020-12-31 22:00:00+00:00       63505.0      63200.0        63800.0
# 157821 2020-12-31 22:30:00+00:00       64331.0      65200.0        65800.0
# 157822 2020-12-31 23:00:00+00:00       66853.0      67000.0        67500.0
# 157823 2020-12-31 23:30:00+00:00       66750.0      67200.0        67600.0
#
#         prevision_neb  prevision_temp  is_holidays
# 157819       3.400764        2.328079          0.0
# 157820       3.479000        2.164250          0.0
# 157821       3.490986        2.029558          0.0
# 157822       3.369000        1.950550          0.0
# 157823       3.045322        1.953771          0.0

# %% [markdown]
# On s'intéresse ici à caractériser les profils journaliers. L'ensemble de données est donc transformé pour que notre jeu d'entrée soit ait en colonnes les points de mesure journaliers de la consommation d'électricité. Avant cela, tout ce qui va être inséré comme entrées du modèle est ici normalisé sur l'ensemble des mesures, puis mis en profils journaliers.
#
# Notre jeu d'entrainement et pour référence est le jeu de données 2012-2018.

# %%
ds = pd.DataFrame({"days" : df_data.utc_datetime.dt.date, "minute":df_data.utc_datetime.dt.minute+60*df_data.utc_datetime.dt.hour})

df_conso, df_temp, df_prevision = make_chronics(df=pd.concat([df_data, ds], axis=1),
                                               toshape_columns=["Consommation", "prevision_temp", "prevision_j-1"],
                                               pivot_indexcol="days", pivot_columncol="minute")

df_conso.head()
# Out:
# minute         0        30       60       90       120      150      180   \
# days
# 2012-01-01  58315.0  58315.0  56231.0  56075.0  55532.0  54911.0  52496.0
# 2012-01-02  55164.0  53643.0  51404.0  50842.0  50399.0  50113.0  48201.0
# 2012-01-03  64600.0  63033.0  60533.0  60426.0  60104.0  59861.0  57915.0
# 2012-01-04  65081.0  63129.0  60564.0  60194.0  59709.0  59353.0  57569.0
# 2012-01-05  67042.0  65123.0  62447.0  62331.0  61889.0  61501.0  59574.0
#
# minute         210      240      270   ...     1140     1170     1200  \
# days                                   ...
# 2012-01-01  50664.0  49161.0  47596.0  ...  57333.0  57786.0  57752.0
# 2012-01-02  47182.0  46306.0  46294.0  ...  73263.0  72615.0  71079.0
# 2012-01-03  56691.0  55743.0  55656.0  ...  76698.0  75660.0  73535.0
# 2012-01-04  56545.0  55655.0  55628.0  ...  78337.0  77173.0  75281.0
# 2012-01-05  58245.0  57258.0  56923.0  ...  78351.0  76928.0  74868.0
#
# minute         1230     1260     1290     1320     1350     1380     1410
# days
# 2012-01-01  56946.0  56054.0  54975.0  53890.0  54348.0  56577.0  55634.0
# 2012-01-02  69050.0  67435.0  65332.0  63756.0  64030.0  65929.0  64902.0
# 2012-01-03  71275.0  69189.0  66829.0  64861.0  64898.0  66939.0  65479.0
# 2012-01-04  72985.0  70927.0  68726.0  66808.0  66878.0  68550.0  67376.0
# 2012-01-05  72432.0  70197.0  68036.0  66269.0  66070.0  68169.0  66910.0
#
# [5 rows x 48 columns]

# %%
df_conso, conso_scaler = apply_scaler(df_data, column="Consommation", df_chronic=df_conso,
                                      reference_window=df_data.utc_datetime.dt.year <=2018)
df_conso.head()
# Out:
# minute          0         30        60        90        120       150   \
# days
# 2012-01-01  0.306926  0.306926  0.135886  0.123082  0.078516  0.027549
# 2012-01-02  0.048313 -0.076520 -0.260282 -0.306408 -0.342766 -0.366239
# 2012-01-03  0.822757  0.694148  0.488965  0.480183  0.453756  0.433812
# 2012-01-04  0.862234  0.702027  0.491509  0.461142  0.421337  0.392118
# 2012-01-05  1.023180  0.865682  0.646053  0.636533  0.600256  0.568412
#
# minute          180       210       240       270   ...      1140      1170  \
# days                                                ...
# 2012-01-01 -0.170658 -0.321017 -0.444373 -0.572818  ...  0.226330  0.263510
# 2012-01-02 -0.523163 -0.606796 -0.678692 -0.679677  ...  1.533758  1.480575
# 2012-01-03  0.274097  0.173639  0.095834  0.088693  ...  1.815680  1.730488
# 2012-01-04  0.245700  0.161657  0.088611  0.086395  ...  1.950198  1.854665
# 2012-01-05  0.410257  0.301181  0.220175  0.192680  ...  1.951348  1.834557
#
# minute          1200      1230      1260      1290      1320      1350  \
# days
# 2012-01-01  0.260719  0.194568  0.121359  0.032801 -0.056248 -0.018659
# 2012-01-02  1.354510  1.187984  1.055435  0.882835  0.753487  0.775975
# 2012-01-03  1.556082  1.370597  1.199392  1.005699  0.844178  0.847215
# 2012-01-04  1.699382  1.510942  1.342035  1.161392  1.003975  1.009720
# 2012-01-05  1.665486  1.465555  1.282122  1.104761  0.959738  0.943405
#
# minute          1380      1410
# days
# 2012-01-01  0.164283  0.086888
# 2012-01-02  0.931833  0.847543
# 2012-01-03  1.014727  0.894900
# 2012-01-04  1.146947  1.050593
# 2012-01-05  1.115677  1.012347
#
# [5 rows x 48 columns]

# %% [markdown]
# 'df_conso' est constitué des profils journaliers de consommation d'lélectricité que l'on va mettre en entrée de notre VAE

# %% [markdown]
# Pour interpréter notre représentation, on peut chercher à visualiser des paramètres connus associés à nos profils journaliers. Ici il s'agit notamment de données calendaires (mois, weekend, jour férié), auxquels on peut rajouter la température moyenne observée sur la journée (par exemple), ou encore la pente moyenne du profil.
#
# Ces informations sont à passer dans calendar_info pour être visualisés dans une projection Tensorboard, et à passer en type et en valeur respectivement dans le dictionnaire factorDesc et factorMatrix pour servir dans l'évaluation des latents.

# %%
#importation des données calendaires
df_calendar = make_df_calendar(pd.DataFrame({"ds" : pd.to_datetime(np.asarray(df_conso.index))}))

df_holidays = pd.concat([df_data[["is_holidays"]],pd.DataFrame({"ds" : pd.to_datetime(ds.days.values)})], axis=1).drop_duplicates(
                                               subset="ds").reset_index(drop= True)

df_calendar = df_calendar.merge(df_holidays, on="ds", how="left").rename(columns={"is_holidays":"is_holiday_day"})

df_calendar.head(5)
# Out:
#           ds  month  weekday  is_weekend  year  is_holiday_day
# 0 2012-01-01      1        6           1  2012             1.0
# 1 2012-01-02      1        0           0  2012             0.0
# 2 2012-01-03      1        1           0  2012             0.0
# 3 2012-01-04      1        2           0  2012             0.0
# 4 2012-01-05      1        3           0  2012             0.0

# %%
#explicit the potential bridge days taken as extended holidays
day_hol = df_calendar[['weekday', 'is_holiday_day']].copy().values
bridge_index=[]
for i in range(day_hol.shape[0]):
    if day_hol[i,1]==1:
        if day_hol[i,0]==1:
            bridge_index.append(i-1)
        elif day_hol[i,0]==3:
            bridge_index.append(i+1)

bridges = np.zeros(day_hol.shape[0])
bridges[np.asarray(bridge_index)] = 1

df_calendar['potential_bridge_holiday'] = bridges
#calendar_info['potential_bridge_holiday'].describe()

# %%
calendar_factors = ["weekday", "is_weekend", "month", "is_holiday_day"]
factors = df_calendar[calendar_factors].copy()
factorDesc = {ff : 'category' for ff in calendar_factors}

temperatureMean= df_temp.mean(axis=1).values.reshape(-1,1)
factorMatrix = np.c_[factors.values,temperatureMean]
factorDesc['temperature']='regressor'

# %% [markdown]
# # Tools to evaluate the representations

# %%
from math import cos, sin
#visualisation d'une représentation 2D dans le notebook
def prez_2D(x_encoded, factorMatrix, temperatureMean):
    proj2D = PCA(2)
    proj = proj2D.fit_transform(x_encoded)
    plt.figure(figsize=(36,18))
    
    #visualisation des mois par un disque de fond coloré
    for i in np.unique(factorMatrix[:,0]):
        i = int(i)
        index = factorMatrix[:,0]==i
        plt.scatter(x=proj[index,0], y=proj[index,1], c= factorMatrix[index,2], marker = 'o', s=500, alpha=0.5, cmap = 'Paired')

    plt.colorbar().set_label('month');
    
    #visualisation de la température par la coloration graduelle du jour de la semaine
    for i in np.unique(factorMatrix[:,0]):
        i = int(i)
        index = factorMatrix[:,0]==i
        plt.scatter(x=proj[index,0], y=proj[index,1], c= temperatureMean[index].ravel(), marker = '$'+str(i)+'$', s=200)

    plt.colorbar().set_label('temperature');
    
def prez_3D(x_encoded, factorMatrix, temperatureMean):
    proj3D = PCA(3)
    proj_z = proj3D.fit_transform(x_encoded)
    plt.figure(figsize=(36,18))
    
    proj = proj_z[:,:2]
    third = proj_z[:,2]
    
    proj = proj + np.tile(third.reshape(-1,1), (1,2)) * np.tile(np.array([[-cos(0.785),sin(0.785)]]),(nPoints,1))
    
    size = 300  + (1.- np.exp(-third / max(third))) * 800
    #visualisation des mois par un disque de fond coloré
    for i in np.unique(factorMatrix[:,1]):
        i = int(i)
        index = factorMatrix[:,0]==i
        plt.scatter(x=proj[index,0], y=proj[index,1], c= factorMatrix[index,2], marker = 'o', s=size, alpha=0.5, cmap = 'Paired')

    plt.colorbar().set_label('month');
    
    #visualisation de la température par la coloration graduelle du jour de la semaine
    for i in np.unique(factorMatrix[:,1]):
        i = int(i)
        index = factorMatrix[:,0]==i
        plt.scatter(x=proj[index,0], y=proj[index,1], c= temperatureMean[index], marker = '$'+str(i)+'$', s=200)

    plt.colorbar().set_label('temperature');

# %% [markdown]
# Pour créer une représentation sous tensorboard, la fonction suivante regroupe toutes les étapes. Le booléen includeConsuptionProfileImages active ou non le marqueur des points à l'image des profils de consommation.

# %%
def tensorboardProjection(name_model,x, x_hat, x_encoded, x_conso, calendar_info, log_dir_projector, includeConsumptionProfileImages=True):
    #can take a bit longer to create and load in tensorboard projector, but it looks better in the projector
    if includeConsumptionProfileImages:
        nPoints=1500 #if you want to visualize images of consumption profiles and its recontruction in tensorboard, there is a maximum size that can be handle for a sprite image. 1830 is  
        x_encoded_reduced=x_encoded[0:nPoints,]
        images=createLoadProfileImages(x,x_hat,nPoints)
    else:
        nPoints=df_conso.shape[0]
        
    if includeConsumptionProfileImages:
        sprites=images_to_sprite(images)
        cv2.imwrite(os.path.join(log_dir_projector, 'sprite_4_classes.png'), sprites)
    
    writeMetaData(log_dir_projector,x_conso,calendar_info,nPoints,has_Odd=False)
    if includeConsumptionProfileImages:
        buildProjector(x_encoded_reduced,images=images, log_dir=log_dir_projector)
    else:
        buildProjector(x_encoded,images=None, log_dir=log_dir_projector)
        
    print(log_dir_projector)

# %%
#Visualisation des courbes de charge en entrée et reconstruite par le modèle

def display_loads(x, x_hat,date,mae):
    fig = plt.figure(dpi=100,figsize=(5,5))
    #set(gca,'Color','k')
    plt.plot(scaler_conso.inverse_transform(x), label = 'truth')
    plt.plot(scaler_conso.inverse_transform(x_hat), '--', label = 'reconstruction')
    plt.title(date+' - mean absolute error %0.2f GW' %(mae*std_sc/1000))
    plt.xlabel('hours')
    plt.ylabel('load (MW)')
    plt.xlim((0,48))
    plt.xticks([5,11,17,23,29,35,41], [3,6,9,12,15,18,21])
    plt.legend(loc='lower right')
    plt.grid();

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     <font size="+2"> <b> 1. Un modèle classique </b> </font> <hr>
# </div>
#
# ## Rappels
#
# Les autoencodeurs variationnels sont des modèles qui fonctionnent en duo:
# - un encodeur qui traduit les données d'entrée dans un espace latent de dimension arbitrairement choisie. Plus exactement il cherche les paramètres de distribution des variables latentes dans chacune des dimensions.
# - un decodeur qui cherche à reconstruire les entrées à partir des coordonnées dans l'espace latent
#
# Pendant l'appentissage, le lien entre encodeur et decodeur est réalisé par l'échantillage selon les paramètres de distribution appris : chaque échantillon a des coordonnées latentes tirées aléatoirement selon cette dernière, que le décodeur cherche à retraduire dans l'espace de dimension initial.

# %% [markdown]
# ## Construire et entrainer un modèle VAE ou CVAE
#
# Il s'agit dans un premier temps de paramétrer les dimensions des couches de nos réseaux de neurone:
# - celles de l'encodeur e_dim
# - celles du décodeur d_dims
# - les dimensions de notre espace latent z_dim (chaque paramètre de distribution sera donc aussi de dimension z_dim)
# - les dimensions de notre embedding des conditions dans le cas dans CVAE

# %%
# paramètres de l'autoencodeur
z_dim = 4 # le nombre de dimensions voulues dans notre représentation latente
e_dims = [48,35,24,12]# les couches cachées du bloc encodeur; premier nombre = inputs_dim
d_dims = [12,24,35,70,48]# les couches cachées du bloc decodeur; premier nombre = outputs_dim
lr=3e-4 # le learning rate de l'optimiseur
input_dim = df_conso.shape[1]

# %% [markdown]
# Pour les paramètres liés au modèle, il faut rappeler le fonctionnement du VAE. On cherche la maximisation de la borne inférieure de la log-vraissemblance du modèle reconstruit ou ELBO qui se décompose en deux termes :
#
# ELBO $= \mathbb{E}_{q_\phi(z|x)} \log(p_\theta(x|z)) - KL(q_\phi(z|x) \| p(z))$
#
# Dans notre objectif d'apprentissage, cela est traduit par une perte à minimiser de la forme:
#
# Obj $= \|x - \hat{x}\| +  KL(q_\phi(z|x) \| p(z))$.
#
# - L'erreur de reconstruction peut être choisie selon une mesure en norme L1 ou L2. La norme L1 permet notamment d'obtenir des profils avec moins de valeurs abérrantes.
#
# - Un prior $p(z)$ laplacien plutôt que gaussien permet des concentrations plus piquées des groupements similaires, et renvoie plus loin les points atypiques.

# %% [markdown]
# - Par ailleurs, pour faciliter l'apprentissage du modèle de façon structurée dans les dimensions choisies de l'espace latent, l'action peut se porter sur le choix du prior comme sur des critères de régularisation devant le terme de divergence.
#
#     Ces termes de régularisation s'appliquent de la façon suivante :
#
#     Obj $= \|x - \hat{x}\| +  \beta KL(q_\phi(z|x) \| p(z)) + \gamma MMD(q_\phi(z) \| p(z))$ si modèle InfoVAE
#     avec $\beta \in \left[0,1\right] $ et $\gamma \ge 0$ (si possible grand)

# %%
# paramètres de l'entrainement du modèle
epochs = 800
batch_size = 16

# %% [markdown]
# On va mettre en forme ici les facteurs sur lesquels on va rendre la représentation latente agnostique. Attention à normaliser les variables quantitatives et à one-hot encoder les variables catégorielles.

# %%
#on va conditionner sur les profils de température et le mois
calendar_cond = []
condtovae_dims = []
condarray=[]

df_temp, _ = apply_scaler(df_data, column="prevision_temp", df_chronic=df_temp,
                                      reference_window=None)

condarray.append(df_temp.values)
condtovae_dims.append(condarray[-1].shape[1])

for cc in calendar_cond:
    condarray.append(pd.get_dummies(df_calendar[cc], prefix=cc).values)
    condtovae_dims.append(condarray[-1].shape[1])

# %%
vae_params = VAE_params(name=name_model, out_dir = log_dir_model)

# %%
vae_params.set_model_params()
vae_params.set_training_params()
# Out:
# Default values for model architecture are:
# with_embedding  :=  False
# with_Time2Vec  :=  True
# emb_dims  :=  []
# kernel_initializer  :=  glorot_uniform
# bias_initializer  :=  glorot_uniform
# reparametrize  :=  GaussianSampling
# intel_function  :=  scalar_binary
# input_dims  :=  48
# output_dims  :=  48
# t2v_dims  :=  12
# latent_dims  :=  4
# nb_latent_components  :=  2
# nb_encoder_ensemble  :=  1
# encoder_dims  :=  [12, 10, 8, 6]
# encoder_type  :=  NNBlockCond_model
# nb_decoder_outputs  :=  1
# nb_decoder_ensemble  :=  1
# decoder_dims  :=  [6, 12, 24, 48]
# latent_encoder_dims  :=  [4, 3, 3, 4]
# latent_mask  :=  0
# decoder_type  :=  InceptionBlock_model
# embedding_type  :=  EmbeddingBlock_model
# cond_dims  :=  []
# cond_insert  :=  {'encoder': [], 'decoder': []}
# context_dims  :=  None
# leapae_dims  :=  [4, None]
# Default parameters for training are a L2 loss with Adam optimizer with a learning rate of 0.0003

# %%
vae_params.model_params.encoder_dims = e_dims
vae_params.model_params.decoder_dims = d_dims
vae_params.model_params.cond_dims = []
vae_params.model_params.latent_dims = z_dim
vae_params.model_params.input_dims = input_dim
vae_params.model_params.output_dims = input_dim
vae_params.model_params.with_embedding = False
vae_params.model_params.emb_dims = [[48,8],[12,8],6]
vae_params.model_params.nb_encoder_ensemble = 1
vae_params.model_params.with_Time2Vec = False

# %%
loss_weights = {"recon_loss" : 1,
                "kl_loss" : 0.33,
                "info_loss" : 75}

vae_loss = VAELoss(loss_weights = loss_weights, recon_loss = 'mse') #change None to custom_loss if will to use one
vae_loss.options["log_prior_sigma"] = [-1., 0., 1, 2.]

vae_params.training_params.loss = vae_loss
vae_params.training_params.lr = 3e-4

# %%
class CVAEadd_loss(AE_Model):

    def __init__(self, VAE_params):
        AE_Model.__init__(self, VAE_params = VAE_params)

    def build_model(self, VAE_params, custom_encoder_model=None, custom_decoder_model=None, custom_timetovec_model = None):
        """

        :param VAE_params: VAE_params class, subclasses of parameters needed to build each layers of the autoencoders and training paramaters to be used in the compile function
        :param custom_encoder_model: TF Model, to be used as encoder model in the graph
        :param custom_decoder_model: TF Model, to be used as decoder model in the graph
        :return: build graph and compile model in the CVAE Class
        """
        self.VAE_params.model_params = VAE_params.model_params
        if self.VAE_params.model_params.with_embedding :
            assert(len(self.VAE_params.model_params.cond_dims) + 1 == len(self.VAE_params.model_params.emb_dims))

        # getting the graph inputs
        x_inputs = Input(shape=(self.VAE_params.model_params.input_dims,), name="x_inputs")
        c_inputs = []
        context_inputs = []

        for i, c_dims in enumerate(self.VAE_params.model_params.cond_dims):
            c_inputs.append(Input(shape=(c_dims,), name="cond_inputs_{}".format(i)))

        if self.VAE_params.model_params.context_dims is not None:
            context_inputs = [Input(shape=(self.VAE_params.model_params.context_dims,), name="context_inputs")]
        
        inputs = [x_inputs] + c_inputs + context_inputs

        # Setting the AE architecture
        if self.VAE_params.model_params.with_embedding:
            self.cond_embedding = build_embedding_model(self, model_params=self.VAE_params.model_params)

        if self.VAE_params.model_params.with_Time2Vec and custom_timetovec_model is not None: 
            self.timetovec_model = custom_timetovec_model

        elif self.VAE_params.model_params.with_Time2Vec and custom_timetovec_model is None: 
            self.timetovec_model = build_time2vec_model(self, model_params=self.VAE_params.model_params)
        
        if custom_encoder_model is not None:
            self.encoder = custom_encoder_model
        elif self.VAE_params.model_params.with_Time2Vec :
            self.encoder = build_t2vencoder_model(self, model_params=self.VAE_params.model_params)
        else:
            self.encoder = build_encoder_model(self, model_params=self.VAE_params.model_params)

        if custom_decoder_model is not None:
            self.decoder = custom_decoder_model
        else:
            self.decoder = build_decoder_model(self, model_params=self.VAE_params.model_params)

        # Model AE graph
        #time2vec
        if self.VAE_params.model_params.with_Time2Vec:
            t2v_outputs = self.timetovec_model(inputs)
            #encoding
            enc_outputs = self.encoder([t2v_outputs])
        else:    
            enc_outputs = self.encoder([inputs])
            
        if (self.VAE_params.model_params.nb_latent_components == 1):
            dec_inputs = [enc_outputs] + c_inputs
        else:
            z = Lambda(eval(self.VAE_params.model_params.reparametrize), name="reparametrizing_layer")(enc_outputs)
            dec_inputs = [z] + c_inputs

        #decoding
        dec_outputs = self.decoder(dec_inputs)

        if self.VAE_params.model_params.nb_decoder_outputs == 1:
            x_hat = dec_outputs
        else:
            x_hat = Lambda(eval(self.VAE_params.model_params.reparametrize), name="loglikelihood_layer")(dec_outputs)

        self.model = Model(inputs=inputs, outputs=x_hat, name="cvae")

        vae_args = dict(
            latent_components=enc_outputs,
            latent_sampling=dec_inputs[0],
            cond_true=c_inputs,
            y_true = x_inputs,
            y_pred = x_hat,
            dec_outputs = dec_outputs
        )
        if self.VAE_params.model_params.with_embedding:
            vae_args.update(dict(embedding_outputs=self.cond_embedding(c_inputs)))


        self.model.summary()
        self.blocks.append("model")

        if self.VAE_params.model_params.with_embedding:
            self.cond_embedding.summary()
            self.blocks.append("cond_embedding")

        if self.VAE_params.model_params.with_Time2Vec:
            self.timetovec_model.summary()
            self.blocks.append("timetovec_model")

        self.encoder.summary()
        self.blocks.append("encoder")
        
        self.decoder.summary()
        self.blocks.append("decoder")

        # Training objectives settings
        optimizer = self.VAE_params.training_params.optimizer(self.VAE_params.training_params.lr)
        if len(list(self.VAE_params.training_params.loss.loss_weights.keys()))> 1:
            vae_loss = self.VAE_params.training_params.loss._get_loss_function2(**vae_args)
            for id, metric in enumerate(vae_loss):
                self.model.add_loss(metric)
                self.model.add_metric(metric,aggregation='mean', name=list(self.VAE_params.training_params.loss.loss_weights.keys())[id])

        print("Losses and associated weight involved in the model: ")
        [print(loss_key, " : ",
               self.VAE_params.training_params.loss.loss_weights[loss_key]) for loss_key in self.VAE_params.training_params.loss.losses.keys()]

        self.model.compile(#loss=self.VAE_params.training_params.loss.losses["recon_loss"],
                           #loss_weights=self.VAE_params.training_params.loss.loss_weights["recon_loss"],
                           loss=None,
                           optimizer=optimizer, experimental_run_tf_function=False)

# %%
new_cae=CVAEadd_loss(vae_params)
new_cae.VAE_params.__dict__
# Out:
# {'name': 'vae_test',
#  'folder': '/home/hermezlor/Documents/cvae-env/VAE/Results/logs/vae_test',
#  'model_params': <src.params_class.VAEModelParams at 0x7f673175e670>,
#  'training_params': <src.params_class.VAETrainingParams at 0x7f673175e7f0>}

# %%
new_cae.build_model(vae_params)
# Out:
# Model: "cvae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  x_inputs (InputLayer)          [(None, 48)]         0           []
#
#  encoder (Functional)           [(None, 4),          5335        ['x_inputs[0][0]']
#                                  (None, 4)]
#
#  reparametrizing_layer (Lambda)  (None, 4)           0           ['encoder[0][0]',
#                                                                   'encoder[0][1]']
#
#  decoder (Functional)           (None, 48)           23543       ['reparametrizing_layer[0][0]']
#
# ==================================================================================================
# Total params: 28,878
# Trainable params: 28,878
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  enc_inputs (InputLayer)        [(None, 48)]         0           []
#
#  encoder_block_0 (Functional)   (None, 12)           5231        ['enc_inputs[0][0]']
#
#  latent_dense_0_1 (Dense)       (None, 4)            52          ['encoder_block_0[0][0]']
#
#  latent_dense_0_2 (Dense)       (None, 4)            52          ['encoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 5,335
# Trainable params: 5,335
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoded_inputs (InputLayer)  [(None, 4)]              0
#
#  decoder_block_0 (Functional  (None, 193)              14231
#  )
#
#  dec_output_0_1 (Dense)      (None, 48)                9312
#
# =================================================================
# Total params: 23,543
# Trainable params: 23,543
# Non-trainable params: 0
# _________________________________________________________________
# Losses and associated weight involved in the model:
# recon_loss  :  1
# kl_loss  :  0.33
# info_loss  :  75

# %%
train_set = df_calendar.year.values <= 2018
test_set = df_calendar.year.values == 2019

input_cvae = df_conso.values[train_set,:]
output_cvae = df_conso.values[train_set,:]

# %%
from tensorflow.keras.callbacks import EarlyStopping
earl_stop = EarlyStopping(
    monitor='val_loss', min_delta=0, patience=100, verbose=0, mode='auto',
    baseline=None, restore_best_weights=True
)

# %%
new_cae.train(input_cvae, output_cvae, epochs= 2000, verbose=1,
              batch_size=batch_size, callbacks=[earl_stop])
# Out:
# ## START TRAINING ##
# Epoch 1/2000
# 144/144 [==============================] - 3s 6ms/step - loss: 18.3920 - recon_loss: 7.0099 - kl_loss: 2.0389 - info_loss: 9.3432 - val_loss: 12.2760 - val_recon_loss: 1.6617 - val_kl_loss: 2.8441 - val_info_loss: 7.7702
# Epoch 2/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 6.8730 - recon_loss: 1.1941 - kl_loss: 2.6285 - info_loss: 3.0504 - val_loss: 6.7913 - val_recon_loss: 0.7069 - val_kl_loss: 2.6579 - val_info_loss: 3.4264
# Epoch 3/2000
# 144/144 [==============================] - 0s 3ms/step - loss:
2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5263 - recon_loss: 0.1877 - kl_loss: 1.8572 - info_loss: 0.4814 - val_loss: 2.4407 - val_recon_loss: 0.1577 - val_kl_loss: 1.7984 - val_info_loss: 0.4845
# Epoch 424/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5281 - recon_loss: 0.1913 - kl_loss: 1.8598 - info_loss: 0.4769 - val_loss: 2.5564 - val_recon_loss: 0.1538 - val_kl_loss: 1.7931 - val_info_loss: 0.6095
# Epoch 425/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5286 - recon_loss: 0.1994 - kl_loss: 1.8519 - info_loss: 0.4773 - val_loss: 2.5675 - val_recon_loss: 0.1633 - val_kl_loss: 1.9664 - val_info_loss: 0.4379
# Epoch 426/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5745 - recon_loss: 0.1908 - kl_loss: 1.9042 - info_loss: 0.4795 - val_loss: 2.5551 - val_recon_loss: 0.1659 - val_kl_loss: 1.8224 - val_info_loss: 0.5668
# Epoch 427/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5463 - recon_loss: 0.1911 - kl_loss: 1.8690 - info_loss: 0.4862 - val_loss: 2.5525 - val_recon_loss: 0.1719 - val_kl_loss: 1.7839 - val_info_loss: 0.5968
# Epoch 428/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5284 - recon_loss: 0.1936 - kl_loss: 1.8501 - info_loss: 0.4847 - val_loss: 2.5537 - val_recon_loss: 0.1957 - val_kl_loss: 1.7852 - val_info_loss: 0.5727
# Epoch 429/2000
# 144/144 [==============================] - 1s 5ms/step - loss: 2.5590 - recon_loss: 0.1943 - kl_loss: 1.8745 - info_loss: 0.4902 - val_loss: 2.5349 - val_recon_loss: 0.1540 - val_kl_loss: 1.9190 - val_info_loss: 0.4619
# ## END TRAINING ##
# ## MODEL SAVED ##

# %%
plt.plot(new_cae.training_history.history['recon_loss'])
plt.plot(new_cae.training_history.history['kl_loss'])
plt.plot(new_cae.training_history.history['info_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.yscale('log')
plt.legend(['recons', 'kl', 'info'], loc='upper right')
plt.show()

# %%
x_encoded = new_cae.encoder.predict(input_cvae)[0]
model_eval, importanceMatrix =evaluate_latent_code(x_encoded, factorMatrix[train_set,:], factorDesc, orthogonalize=True, normalize_information=True)
#normalize_information normalise le score avec le minimum obtenu avec une projection aléatoire
display_evaluation_latent_code(model_eval, z_dim, factorDesc)
prez_2D(x_encoded, factorMatrix[train_set,:], temperatureMean[train_set])

# %%
vae_params = VAE_params(name=name_model, out_dir = log_dir_model)
vae_params.set_model_params()
vae_params.set_training_params()
vae_params.model_params.encoder_dims = e_dims
vae_params.model_params.decoder_dims = d_dims
vae_params.model_params.cond_dims = []
vae_params.model_params.latent_dims = z_dim
vae_params.model_params.input_dims = input_dim
vae_params.model_params.output_dims = input_dim
vae_params.model_params.with_embedding = False
vae_params.model_params.emb_dims = [[48,8],[12,8],6]
vae_params.model_params.nb_encoder_ensemble = 1
vae_params.model_params.with_Time2Vec = False
loss_weights = {"recon_loss" : 1,
                "kl_loss" : 0.33,
                "info_loss" : 75}

vae_loss = VAELoss(loss_weights = loss_weights, recon_loss = 'mse') #change None to custom_loss if will to use one
vae_loss.options["log_prior_sigma"] = [-1., 0., 1, 2.]

vae_params.training_params.loss = vae_loss
vae_params.training_params.lr = 3e-4
# Out:
# Default values for model architecture are:
# with_embedding  :=  False
# with_Time2Vec  :=  True
# emb_dims  :=  []
# kernel_initializer  :=  glorot_uniform
# bias_initializer  :=  glorot_uniform
# reparametrize  :=  GaussianSampling
# intel_function  :=  scalar_binary
# input_dims  :=  48
# output_dims  :=  48
# t2v_dims  :=  12
# latent_dims  :=  4
# nb_latent_components  :=  2
# nb_encoder_ensemble  :=  1
# encoder_dims  :=  [12, 10, 8, 6]
# encoder_type  :=  NNBlockCond_model
# nb_decoder_outputs  :=  1
# nb_decoder_ensemble  :=  1
# decoder_dims  :=  [6, 12, 24, 48]
# latent_encoder_dims  :=  [4, 3, 3, 4]
# latent_mask  :=  0
# decoder_type  :=  InceptionBlock_model
# embedding_type  :=  EmbeddingBlock_model
# cond_dims  :=  []
# cond_insert  :=  {'encoder': [], 'decoder': []}
# context_dims  :=  None
# leapae_dims  :=  [4, None]
# Default parameters for training are a L2 loss with Adam optimizer with a learning rate of 0.0003

# %%
from src.models import CVAE
new_cae2=CVAE(vae_params)
new_cae2.VAE_params.__dict__

# %%
new_cae2.build_model(vae_params)
# Out:
# Model: "cvae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  x_inputs (InputLayer)          [(None, 48)]         0           []
#
#  encoder (Functional)           [(None, 4),          5335        ['x_inputs[0][0]']
#                                  (None, 4)]
#
#  reparametrizing_layer (Lambda)  (None, 4)           0           ['encoder[0][0]',
#                                                                   'encoder[0][1]']
#
#  decoder (Functional)           (None, 48)           23543       ['reparametrizing_layer[0][0]']
#
# ==================================================================================================
# Total params: 28,878
# Trainable params: 28,878
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  enc_inputs (InputLayer)        [(None, 48)]         0           []
#
#  encoder_block_0 (Functional)   (None, 12)           5231        ['enc_inputs[0][0]']
#
#  latent_dense_0_1 (Dense)       (None, 4)            52          ['encoder_block_0[0][0]']
#
#  latent_dense_0_2 (Dense)       (None, 4)            52          ['encoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 5,335
# Trainable params: 5,335
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoded_inputs (InputLayer)  [(None, 4)]              0
#
#  decoder_block_0 (Functional  (None, 193)              14231
#  )
#
#  dec_output_0_1 (Dense)      (None, 48)                9312
#
# =================================================================
# Total params: 23,543
# Trainable params: 23,543
# Non-trainable params: 0
# _________________________________________________________________
# Losses and associated weight involved in the model:
# recon_loss  :  1
# kl_loss  :  0.33
# info_loss  :  75

# %%
from tensorflow.keras.callbacks import EarlyStopping
earl_stop = EarlyStopping(
    monitor='val_loss', min_delta=0, patience=100, verbose=0, mode='auto',
    baseline=None, restore_best_weights=True
)

# %%
new_cae2.train(input_cvae, output_cvae, epochs= 2000, verbose=1,
              batch_size=batch_size, callbacks=[earl_stop])
# Out:
# ## START TRAINING ##
# Epoch 1/2000
# 144/144 [==============================] - 3s 5ms/step - loss: 27.1940 - val_loss: 15.2124
# Epoch 2/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 8.4593 - val_loss: 6.5948
# Epoch 3/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 5.0407 - val_loss: 4.1605
# Epoch 4/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 3.9508 - val_loss: 3.3977
# Epoch 5/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 3.5805 - val_loss: 3.1163
# Epoch 6/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 3.4183 - val_loss: 3.0748
# Epoch 7/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 3.2516 - val_loss: 2.9687
# Epoch 8/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 3.1583 - val_loss: 2.8964
# Epoch 9/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 3.1291 - val_loss: 2.9813
# Epoch 10/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 3.0884 - val_loss: 2.9206
# Epoch 11/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 3.0081 - val_loss: 2.9253
# Epoch 12/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.9598 - val_loss: 2.8855
# Epoch 13/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.9389 - val_loss: 2.7739
# Epoch 14/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.9184 - val_loss: 2.7734
# Epoch 15/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.8274 - val_loss: 2.7959
# Epoch 16/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.8161 - val_loss: 2.8478
# Epoch 17/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.7869 - val_loss: 2.8432
# Epoch 18/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.7855 - val_loss: 2.5822
# Epoch 19/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.7577 - val_loss: 2.7921
# Epoch 20/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.7487 - val_loss: 2.7514
# Epoch 21/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.7430 - val_loss: 2.6682
# Epoch 22/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.7400 - val_loss: 2.6949
# Epoch 23/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.7545 - val_loss: 2.7016
# Epoch 24/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.7099 - val_loss: 2.7051
# Epoch 25/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.7000 - val_loss: 2.7864
# Epoch 26/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6912 - val_loss: 2.7492
# Epoch 27/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6909 - val_loss: 2.6327
# Epoch 28/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6826 - val_loss: 2.5769
# Epoch 29/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6991 - val_loss: 2.6450
# Epoch 30/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6871 - val_loss: 2.7308
# Epoch 31/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.7053 - val_loss: 2.6471
# Epoch 32/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6434 - val_loss: 2.7547
# Epoch 33/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6702 - val_loss: 2.6844
# Epoch 34/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6845 - val_loss: 2.7183
# Epoch 35/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6765 - val_loss: 2.7639
# Epoch 36/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6703 - val_loss: 2.5437
# Epoch 37/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6186 - val_loss: 2.6591
# Epoch 38/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6289 - val_loss: 2.6858
# Epoch 39/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6340 - val_loss: 2.5740
# Epoch 40/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6137 - val_loss: 2.6561
# Epoch 41/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6217 - val_loss: 2.7006
# Epoch 42/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6495 - val_loss: 2.5612
# Epoch 43/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6006 - val_loss: 2.5253
# Epoch 44/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6045 - val_loss: 2.6779
# Epoch 45/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6427 - val_loss: 2.6832
# Epoch 46/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6367 - val_loss: 2.6196
# Epoch 47/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6033 - val_loss: 2.6010
# Epoch 48/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6144 - val_loss: 2.6385
# Epoch 49/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6070 - val_loss: 2.4739
# Epoch 50/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5923 - val_loss: 2.5902
# Epoch 51/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6212 - val_loss: 2.6461
# Epoch 52/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6074 - val_loss: 2.6413
# Epoch 53/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6202 - val_loss: 2.7052
# Epoch 54/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6402 - val_loss: 2.6205
# Epoch 55/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5717 - val_loss: 2.7376
# Epoch 56/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6133 - val_loss: 2.7112
# Epoch 57/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6040 - val_loss: 2.6673
# Epoch 58/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5749 - val_loss: 2.6599
# Epoch 59/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6110 - val_loss: 2.5833
# Epoch 60/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6093 - val_loss: 2.6484
# Epoch 61/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5808 - val_loss: 2.5535
# Epoch 62/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5873 - val_loss: 2.6027
# Epoch 63/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5988 - val_loss: 2.5838
# Epoch 64/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6009 - val_loss: 2.5052
# Epoch 65/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5932 - val_loss: 2.5772
# Epoch 66/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6172 - val_loss: 2.6330
# Epoch 67/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6028 - val_loss: 2.5243
# Epoch 68/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5846 - val_loss: 2.8079
# Epoch 69/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5851 - val_loss: 2.6624
# Epoch 70/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5607 - val_loss: 2.6087
# Epoch 71/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5827 - val_loss: 2.5668
# Epoch 72/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6053 - val_loss: 2.6788
# Epoch 73/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5674 - val_loss: 2.5498
# Epoch 74/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6105 - val_loss: 2.5916
# Epoch 75/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5653 - val_loss: 2.6059
# Epoch 76/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5901 - val_loss: 2.6146
# Epoch 77/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5863 - val_loss: 2.4866
# Epoch 78/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5917 - val_loss: 2.5320
# Epoch 79/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5845 - val_loss: 2.5943
# Epoch 80/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5915 - val_loss: 2.5644
# Epoch 81/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5941 - val_loss: 2.4970
# Epoch 82/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5832 - val_loss: 2.4587
# Epoch 83/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5804 - val_loss: 2.5573
# Epoch 84/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5513 - val_loss: 2.6312
# Epoch 85/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5975 - val_loss: 2.5079
# Epoch 86/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5677 - val_loss: 2.6028
# Epoch 87/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5541 - val_loss: 2.5698
# Epoch 88/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5685 - val_loss: 2.5631
# Epoch 89/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5748 - val_loss: 2.6743
# Epoch 90/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5628 - val_loss: 2.6494
# Epoch 91/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6165 - val_loss: 2.5557
# Epoch 92/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5564 - val_loss: 2.8052
# Epoch 93/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5667 - val_loss: 2.5778
# Epoch 94/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5727 - val_loss: 2.6127
# Epoch 95/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5582 - val_loss: 2.5814
# Epoch 96/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5806 - val_loss: 2.5003
# Epoch 97/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5735 - val_loss: 2.7480
# Epoch 98/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5554 - val_loss: 2.6074
# Epoch 99/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5768 - val_loss: 2.6303
# Epoch 100/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5676 - val_loss: 2.5780
# Epoch 101/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5784 - val_loss: 2.4971
# Epoch 102/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5702 - val_loss: 2.5307
# Epoch 103/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5732 - val_loss: 2.6246
# Epoch 104/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5660 - val_loss: 2.5564
# Epoch 105/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5957 - val_loss: 2.5832
# Epoch 106/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5806 - val_loss: 2.5478
# Epoch 107/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5843 - val_loss: 2.6248
# Epoch 108/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5513 - val_loss: 2.6686
# Epoch 109/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5424 - val_loss: 2.5359
# Epoch 110/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5728 - val_loss: 2.6267
# Epoch 111/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5539 - val_loss: 2.6891
# Epoch 112/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5646 - val_loss: 2.5303
# Epoch 113/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5602 - val_loss: 2.6556
# Epoch 114/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5469 - val_loss: 2.6934
# Epoch 115/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5615 - val_loss: 2.5282
# Epoch 116/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5433 - val_loss: 2.5507
# Epoch 117/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5471 - val_loss: 2.5978
# Epoch 118/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5628 - val_loss: 2.5852
# Epoch 119/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5860 - val_loss: 2.5568
# Epoch 120/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5932 - val_loss: 2.5995
# Epoch 121/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.6075 - val_loss: 2.6028
# Epoch 122/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5525 - val_loss: 2.6153
# Epoch 123/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5639 - val_loss: 2.5375
# Epoch 124/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5530 - val_loss: 2.5436
# Epoch 125/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5821 - val_loss: 2.6359
# Epoch 126/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5725 - val_loss: 2.6555
# Epoch 127/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5854 - val_loss: 2.5989
# Epoch 128/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5744 - val_loss: 2.6166
# Epoch 129/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5711 - val_loss: 2.6493
# Epoch 130/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5696 - val_loss: 2.5592
# Epoch 131/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5559 - val_loss: 2.5918
# Epoch 132/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5588 - val_loss: 2.5991
# Epoch 133/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5502 - val_loss: 2.5162
# Epoch 134/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5448 - val_loss: 2.6596
# Epoch 135/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5533 - val_loss: 2.5274
# Epoch 136/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5462 - val_loss: 2.4827
# Epoch 137/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5698 - val_loss: 2.5640
# Epoch 138/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5478 - val_loss: 2.4668
# Epoch 139/2000
# 144/144 [==============================] - 1s 4ms/step - loss: 2.5830 - val_loss: 2.5779
# Epoch 140/2000
# 144/144 [==============================] - 1s 4ms/step - loss: 2.5624 - val_loss: 2.5500
# Epoch 141/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5732 - val_loss: 2.5376
# Epoch 142/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5774 - val_loss: 2.5117
# Epoch 143/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5476 - val_loss: 2.5421
# Epoch 144/2000
# 144/144 [==============================] - 1s 3ms/step - loss: 2.5407 - val_loss: 2.5590
# Epoch 145/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5714 - val_loss: 2.5803
# Epoch 146/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5832 - val_loss: 2.5901
# Epoch 147/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5916 - val_loss: 2.6022
# Epoch 148/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5398 - val_loss: 2.5321
# Epoch 149/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5579 - val_loss: 2.6065
# Epoch 150/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5652 - val_loss: 2.5954
# Epoch 151/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5755 - val_loss: 2.6925
# Epoch 152/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5534 - val_loss: 2.4036
# Epoch 153/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5767 - val_loss: 2.4728
# Epoch 154/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5625 - val_loss: 2.7096
# Epoch 155/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5560 - val_loss: 2.6363
# Epoch 156/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5329 - val_loss: 2.4873
# Epoch 157/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5556 - val_loss: 2.5292
# Epoch 158/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5672 - val_loss: 2.6029
# Epoch 159/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5666 - val_loss: 2.6493
# Epoch 160/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5386 - val_loss: 2.5627
# Epoch 161/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5403 - val_loss: 2.5022
# Epoch 162/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5682 - val_loss: 2.5532
# Epoch 163/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5492 - val_loss: 2.5886
# Epoch 164/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5476 - val_loss: 2.5366
# Epoch 165/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5451 - val_loss: 2.5656
# Epoch 166/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5708 - val_loss: 2.5578
# Epoch 167/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5381 - val_loss: 2.6001
# Epoch 168/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5646 - val_loss: 2.5442
# Epoch 169/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5264 - val_loss: 2.6629
# Epoch 170/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5396 - val_loss: 2.5972
# Epoch 171/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5688 - val_loss: 2.6095
# Epoch 172/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5682 - val_loss: 2.6487
# Epoch 173/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5689 - val_loss: 2.4943
# Epoch 174/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5643 - val_loss: 2.5367
# Epoch 175/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5347 - val_loss: 2.5949
# Epoch 176/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5663 - val_loss: 2.5503
# Epoch 177/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5413 - val_loss: 2.5399
# Epoch 178/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5651 - val_loss: 2.4968
# Epoch 179/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5383 - val_loss: 2.5864
# Epoch 180/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5519 - val_loss: 2.6144
# Epoch 181/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5417 - val_loss: 2.6562
# Epoch 182/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5430 - val_loss: 2.6029
# Epoch 183/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5459 - val_loss: 2.6651
# Epoch 184/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5501 - val_loss: 2.5265
# Epoch 185/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5430 - val_loss: 2.4991
# Epoch 186/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5580 - val_loss: 2.5927
# Epoch 187/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5410 - val_loss: 2.6037
# Epoch 188/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5291 - val_loss: 2.4116
# Epoch 189/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5227 - val_loss: 2.5343
# Epoch 190/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5473 - val_loss: 2.6080
# Epoch 191/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5319 - val_loss: 2.6398
# Epoch 192/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5774 - val_loss: 2.5500
# Epoch 193/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5643 - val_loss: 2.5778
# Epoch 194/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5602 - val_loss: 2.5240
# Epoch 195/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5595 - val_loss: 2.6712
# Epoch 196/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5389 - val_loss: 2.4795
# Epoch 197/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5558 - val_loss: 2.5168
# Epoch 198/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5373 - val_loss: 2.5787
# Epoch 199/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5653 - val_loss: 2.6258
# Epoch 200/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5534 - val_loss: 2.5568
# Epoch 201/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5163 - val_loss: 2.6113
# Epoch 202/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5634 - val_loss: 2.6147
# Epoch 203/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5481 - val_loss: 2.5916
# Epoch 204/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5622 - val_loss: 2.6007
# Epoch 205/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5546 - val_loss: 2.5530
# Epoch 206/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5424 - val_loss: 2.5386
# Epoch 207/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5501 - val_loss: 2.5270
# Epoch 208/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5160 - val_loss: 2.5668
# Epoch 209/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5441 - val_loss: 2.5898
# Epoch 210/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5531 - val_loss: 2.6079
# Epoch 211/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5462 - val_loss: 2.5677
# Epoch 212/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5629 - val_loss: 2.5680
# Epoch 213/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5505 - val_loss: 2.5949
# Epoch 214/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5361 - val_loss: 2.4503
# Epoch 215/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5392 - val_loss: 2.6272
# Epoch 216/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5428 - val_loss: 2.5226
# Epoch 217/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5265 - val_loss: 2.6320
# Epoch 218/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5245 - val_loss: 2.5617
# Epoch 219/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5576 - val_loss: 2.6383
# Epoch 220/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5478 - val_loss: 2.5623
# Epoch 221/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5688 - val_loss: 2.5667
# Epoch 222/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5316 - val_loss: 2.5289
# Epoch 223/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5335 - val_loss: 2.4815
# Epoch 224/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5424 - val_loss: 2.5091
# Epoch 225/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5390 - val_loss: 2.5259
# Epoch 226/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5304 - val_loss: 2.5786
# Epoch 227/2000
# 144/144 [==============================] - 1s 5ms/step - loss: 2.5442 - val_loss: 2.5092
# Epoch 228/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5401 - val_loss: 2.5982
# Epoch 229/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5424 - val_loss: 2.6608
# Epoch 230/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5487 - val_loss: 2.5582
# Epoch 231/2000
# 144/144 [==============================] - 1s 4ms/step - loss: 2.5296 - val_loss: 2.4362
# Epoch 232/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5559 - val_loss: 2.4946
# Epoch 233/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5416 - val_loss: 2.7095
# Epoch 234/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5550 - val_loss: 2.5989
# Epoch 235/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5517 - val_loss: 2.6337
# Epoch 236/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5436 - val_loss: 2.6453
# Epoch 237/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5385 - val_loss: 2.5211
# Epoch 238/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5488 - val_loss: 2.4821
# Epoch 239/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5672 - val_loss: 2.5811
# Epoch 240/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5339 - val_loss: 2.6036
# Epoch 241/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5581 - val_loss: 2.5593
# Epoch 242/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5583 - val_loss: 2.5190
# Epoch 243/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5624 - val_loss: 2.5312
# Epoch 244/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5439 - val_loss: 2.5328
# Epoch 245/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5402 - val_loss: 2.4647
# Epoch 246/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5298 - val_loss: 2.6177
# Epoch 247/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5594 - val_loss: 2.6712
# Epoch 248/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5491 - val_loss: 2.5721
# Epoch 249/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5469 - val_loss: 2.5860
# Epoch 250/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5986 - val_loss: 2.5369
# Epoch 251/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5505 - val_loss: 2.5151
# Epoch 252/2000
# 144/144 [==============================] - 0s 3ms/step - loss: 2.5274 - val_loss: 2.6809
# ## END TRAINING ##
# ## MODEL SAVED ##

# %%
x_encoded = new_cae2.encoder.predict(input_cvae)[0]
model_eval, importanceMatrix =evaluate_latent_code(x_encoded, factorMatrix[train_set,:], factorDesc, orthogonalize=True, normalize_information=True)
#normalize_information normalise le score avec le minimum obtenu avec une projection aléatoire
display_evaluation_latent_code(model_eval, z_dim, factorDesc)
prez_2D(x_encoded, factorMatrix[train_set,:], temperatureMean[train_set])

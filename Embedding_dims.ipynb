# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <hr> <center> <font size="+3.5"> <b> Trouver les meilleures dimensions d'embedding pour augmenter le démêlement de l'information dans l'espace latent.</b> </font> </center> <hr>
# </div>

# %% [markdown]
# <div class="alert alert-block" role="alert">
#     <center><b> <u>Auteur :</u>  Lorenzo HERMEZ  </b></center>
# </div>
# <div class="alert alert-block" role="alert">
#     <center> <font size="+1.5"> <b>  08 mars 2022  </b>  </font> </center>
# </div>

# %% [markdown]
# # Table de contenu
#
# ## 0. Préparation de l'environnement de travail
# - Chargement des modules
# - Mise en forme des données
# - Définition de quelques fonctions utiles
#
# ## 1. Construction des différents modèles.
# - Construction des modèles "embeddés" de manières différentes
# - Entrainement des modèles
# - Évaluation des représentations obtenues
# - comparaison des modèles

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     <font size="+2"> <b> 0. Préparation de l'environnement de travail </b> </font> <hr>
# </div>

# %% [markdown]
# ### Chargement des modules et mise en forme des données

# %%
#import external libraries
import sys
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

# %%
#root git folder 

path_second_folder = %pwd #"/home/hermezlor/Documents/cvae-env/VAE/"
save_path = os.path.join(path_second_folder,"Results/Embedding_dims") #"/home/goubetcle/Documents/VAE/"
log_dir_model=os.path.join(save_path,"logs")

#add  to path root git folder 
sys.path.append(path_second_folder)

# %%
sys.path.append(path_second_folder+'/src')

from src.models import *
from src.loss_class import *
from src.params_class import *
import src.AE_blocks
from src.metrics import *
from src.utils import *
from src.udr_score import *

# %load_ext autoreload
# %autoreload 2
# Out:
# 2022-07-21 09:17:45.935729: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-21 09:17:45.935754: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-07-21 09:17:49.395801: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-21 09:17:49.395824: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-21 09:17:49.395841: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (gm0winl472.bureau.si.interne): /proc/driver/nvidia/version does not exist
# 2022-07-21 09:17:49.396235: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Les données de consommation et de température sont des prises de mesure par pas de temps 30 minutes pendant 5 années de décembre 2012 à décembre 2020.

# %%
# Load dataframe
dataset_csv = os.path.join('data', "dataset_2012_2020.csv")
df_data = pd.read_csv(dataset_csv, sep=";",)
df_data.utc_datetime = pd.to_datetime(df_data.utc_datetime, utc=True)

#Visualize data frame head
df_data.tail(5)
# Out:
#                     utc_datetime  Consommation  prevision_j  prevision_j-1  \
# 157819 2020-12-31 21:30:00+00:00       64423.0      63700.0        64400.0
# 157820 2020-12-31 22:00:00+00:00       63505.0      63200.0        63800.0
# 157821 2020-12-31 22:30:00+00:00       64331.0      65200.0        65800.0
# 157822 2020-12-31 23:00:00+00:00       66853.0      67000.0        67500.0
# 157823 2020-12-31 23:30:00+00:00       66750.0      67200.0        67600.0
#
#         prevision_neb  prevision_temp  is_holidays
# 157819       3.400764        2.328079          0.0
# 157820       3.479000        2.164250          0.0
# 157821       3.490986        2.029558          0.0
# 157822       3.369000        1.950550          0.0
# 157823       3.045322        1.953771          0.0

# %% [markdown]
# On s'intéresse ici à caractériser les profils journaliers. L'ensemble de données est donc transformé pour que notre jeu d'entrée soit ait en colonnes les points de mesure journaliers de la consommation d'électricité. Avant cela, tout ce qui va être inséré comme entrées du modèle est ici normalisé sur l'ensemble des mesures, puis mis en profils journaliers.
#
# Notre jeu d'entrainement et pour référence est le jeu de données 2012-2018.

# %%
ds = pd.DataFrame({"days" : df_data.utc_datetime.dt.date, "minute":df_data.utc_datetime.dt.minute+60*df_data.utc_datetime.dt.hour})

df_conso, df_temp, df_prevision = make_chronics(df=pd.concat([df_data, ds], axis=1),
                                               toshape_columns=["Consommation", "prevision_temp", "prevision_j-1"],
                                               pivot_indexcol="days", pivot_columncol="minute")

df_conso.head()
# Out:
# minute         0        30       60       90       120      150      180   \
# days
# 2012-01-01  58315.0  58315.0  56231.0  56075.0  55532.0  54911.0  52496.0
# 2012-01-02  55164.0  53643.0  51404.0  50842.0  50399.0  50113.0  48201.0
# 2012-01-03  64600.0  63033.0  60533.0  60426.0  60104.0  59861.0  57915.0
# 2012-01-04  65081.0  63129.0  60564.0  60194.0  59709.0  59353.0  57569.0
# 2012-01-05  67042.0  65123.0  62447.0  62331.0  61889.0  61501.0  59574.0
#
# minute         210      240      270   ...     1140     1170     1200  \
# days                                   ...
# 2012-01-01  50664.0  49161.0  47596.0  ...  57333.0  57786.0  57752.0
# 2012-01-02  47182.0  46306.0  46294.0  ...  73263.0  72615.0  71079.0
# 2012-01-03  56691.0  55743.0  55656.0  ...  76698.0  75660.0  73535.0
# 2012-01-04  56545.0  55655.0  55628.0  ...  78337.0  77173.0  75281.0
# 2012-01-05  58245.0  57258.0  56923.0  ...  78351.0  76928.0  74868.0
#
# minute         1230     1260     1290     1320     1350     1380     1410
# days
# 2012-01-01  56946.0  56054.0  54975.0  53890.0  54348.0  56577.0  55634.0
# 2012-01-02  69050.0  67435.0  65332.0  63756.0  64030.0  65929.0  64902.0
# 2012-01-03  71275.0  69189.0  66829.0  64861.0  64898.0  66939.0  65479.0
# 2012-01-04  72985.0  70927.0  68726.0  66808.0  66878.0  68550.0  67376.0
# 2012-01-05  72432.0  70197.0  68036.0  66269.0  66070.0  68169.0  66910.0
#
# [5 rows x 48 columns]

# %%
df_conso, conso_scaler = apply_scaler(df_data, column="Consommation", df_chronic=df_conso,
                                      reference_window=df_data.utc_datetime.dt.year <=2018)
df_conso.head()
# Out:
# minute          0         30        60        90        120       150   \
# days
# 2012-01-01  0.306926  0.306926  0.135886  0.123082  0.078516  0.027549
# 2012-01-02  0.048313 -0.076520 -0.260282 -0.306408 -0.342766 -0.366239
# 2012-01-03  0.822757  0.694148  0.488965  0.480183  0.453756  0.433812
# 2012-01-04  0.862234  0.702027  0.491509  0.461142  0.421337  0.392118
# 2012-01-05  1.023180  0.865682  0.646053  0.636533  0.600256  0.568412
#
# minute          180       210       240       270   ...      1140      1170  \
# days                                                ...
# 2012-01-01 -0.170658 -0.321017 -0.444373 -0.572818  ...  0.226330  0.263510
# 2012-01-02 -0.523163 -0.606796 -0.678692 -0.679677  ...  1.533758  1.480575
# 2012-01-03  0.274097  0.173639  0.095834  0.088693  ...  1.815680  1.730488
# 2012-01-04  0.245700  0.161657  0.088611  0.086395  ...  1.950198  1.854665
# 2012-01-05  0.410257  0.301181  0.220175  0.192680  ...  1.951348  1.834557
#
# minute          1200      1230      1260      1290      1320      1350  \
# days
# 2012-01-01  0.260719  0.194568  0.121359  0.032801 -0.056248 -0.018659
# 2012-01-02  1.354510  1.187984  1.055435  0.882835  0.753487  0.775975
# 2012-01-03  1.556082  1.370597  1.199392  1.005699  0.844178  0.847215
# 2012-01-04  1.699382  1.510942  1.342035  1.161392  1.003975  1.009720
# 2012-01-05  1.665486  1.465555  1.282122  1.104761  0.959738  0.943405
#
# minute          1380      1410
# days
# 2012-01-01  0.164283  0.086888
# 2012-01-02  0.931833  0.847543
# 2012-01-03  1.014727  0.894900
# 2012-01-04  1.146947  1.050593
# 2012-01-05  1.115677  1.012347
#
# [5 rows x 48 columns]

# %% [markdown]
# 'df_conso' est constitué des profils journaliers de consommation d'lélectricité que l'on va mettre en entrée de notre VAE

# %% [markdown]
# Pour interpréter notre représentation, on peut chercher à visualiser des paramètres connus associés à nos profils journaliers. Ici il s'agit notamment de données calendaires (mois, weekend, jour férié), auxquels on peut rajouter la température moyenne observée sur la journée (par exemple), ou encore la pente moyenne du profil.
#
# Ces informations sont à passer dans calendar_info pour être visualisés dans une projection Tensorboard, et à passer en type et en valeur respectivement dans le dictionnaire factorDesc et factorMatrix pour servir dans l'évaluation des latents.

# %%
#importation des données calendaires
df_calendar = make_df_calendar(pd.DataFrame({"ds" : pd.to_datetime(np.asarray(df_conso.index))}))

df_holidays = pd.concat([df_data[["is_holidays"]],pd.DataFrame({"ds" : pd.to_datetime(ds.days.values)})], axis=1).drop_duplicates(
                                               subset="ds").reset_index(drop= True)

df_calendar = df_calendar.merge(df_holidays, on="ds", how="left").rename(columns={"is_holidays":"is_holiday_day"})

df_calendar.head(5)
# Out:
#           ds  month  weekday  is_weekend  year  is_holiday_day
# 0 2012-01-01      1        6           1  2012             1.0
# 1 2012-01-02      1        0           0  2012             0.0
# 2 2012-01-03      1        1           0  2012             0.0
# 3 2012-01-04      1        2           0  2012             0.0
# 4 2012-01-05      1        3           0  2012             0.0

# %%
#explicit the potential bridge days taken as extended holidays
day_hol = df_calendar[['weekday', 'is_holiday_day']].copy().values
bridge_index=[]
for i in range(day_hol.shape[0]):
    if day_hol[i,1]==1:
        if day_hol[i,0]==1:
            bridge_index.append(i-1)
        elif day_hol[i,0]==3:
            bridge_index.append(i+1)

bridges = np.zeros(day_hol.shape[0])
bridges[np.asarray(bridge_index)] = 1

df_calendar['potential_bridge_holiday'] = bridges
#calendar_info['potential_bridge_holiday'].describe()

# %%
calendar_factors = ["weekday", "is_weekend", "month", "is_holiday_day"]
factors = df_calendar[calendar_factors].copy()
factorDesc = {ff : 'category' for ff in calendar_factors}

temperatureMean= df_temp.mean(axis=1).values.reshape(-1,1)
factorMatrix = np.c_[factors.values,temperatureMean]
factorDesc['temperature']='regressor'

# %% [markdown]
# ### Définition de quelques fonctions utiles

# %%
from math import cos, sin
#visualisation d'une représentation 2D dans le notebook
def prez_2D(x_encoded, factorMatrix, temperatureMean):
    proj2D = PCA(2)
    proj = proj2D.fit_transform(x_encoded)
    plt.figure(figsize=(36,18))
    
    #visualisation des mois par un disque de fond coloré
    for i in np.unique(factorMatrix[:,0]):
        i = int(i)
        index = factorMatrix[:,0]==i
        plt.scatter(x=proj[index,0], y=proj[index,1], c= factorMatrix[index,2], marker = 'o', s=500, alpha=0.5, cmap = 'Paired')

    plt.colorbar().set_label('month');
    
    #visualisation de la température par la coloration graduelle du jour de la semaine
    for i in np.unique(factorMatrix[:,0]):
        i = int(i)
        index = factorMatrix[:,0]==i
        plt.scatter(x=proj[index,0], y=proj[index,1], c= temperatureMean[index].ravel(), marker = '$'+str(i)+'$', s=200)
    plt.colorbar().set_label('temperature');

def prez_2D_holidays(x_encoded, factorMatrix, temperatureMean):
    proj2D = PCA(2)
    proj = proj2D.fit_transform(x_encoded)
    plt.figure(figsize=(36,18))
    
    #visualisation des mois par un disque de fond coloré
    for i in np.unique(factorMatrix[:,0]):
        i = int(i)
        index = factorMatrix[:,0]==i
        plt.scatter(x=proj[index,0], y=proj[index,1], c= factorMatrix[index,2], marker = 'o', s=500, alpha=0.5, cmap = 'Paired')

    plt.colorbar().set_label('month');
    
    #visualisation de la température par la coloration graduelle du jour de la semaine
    for i in np.unique(factorMatrix[:,0]):
        i = int(i)
        index = factorMatrix[:,0]==i
        plt.scatter(x=proj[index,0], y=proj[index,1], c=temperatureMean[index].ravel(), marker = '$'+str(i)+'$', s=200)

    plt.colorbar().set_label('temperature');
    index = factorMatrix[:,-2]==1
    plt.scatter(x=proj[index,0], y=proj[index,1], color='yellow', marker='*',s=450)
    
def prez_3D(x_encoded, factorMatrix, temperatureMean):
    proj3D = PCA(3)
    proj_z = proj3D.fit_transform(x_encoded)
    plt.figure(figsize=(36,18))
    
    proj = proj_z[:,:2]
    third = proj_z[:,2]
    
    proj = proj + np.tile(third.reshape(-1,1), (1,2)) * np.tile(np.array([[-cos(0.785),sin(0.785)]]),(nPoints,1))
    
    size = 300  + (1.- np.exp(-third / max(third))) * 800
    #visualisation des mois par un disque de fond coloré
    for i in np.unique(factorMatrix[:,1]):
        i = int(i)
        index = factorMatrix[:,0]==i
        plt.scatter(x=proj[index,0], y=proj[index,1], c= factorMatrix[index,2], marker = 'o', s=size, alpha=0.5, cmap = 'Paired')

    plt.colorbar().set_label('month');
    
    #visualisation de la température par la coloration graduelle du jour de la semaine
    for i in np.unique(factorMatrix[:,1]):
        i = int(i)
        index = factorMatrix[:,0]==i
        plt.scatter(x=proj[index,0], y=proj[index,1], c= temperatureMean[index], marker = '$'+str(i)+'$', s=200)

    plt.colorbar().set_label('temperature');

# %% [markdown]
# Pour créer une représentation sous tensorboard, la fonction suivante regroupe toutes les étapes. Le booléen includeConsuptionProfileImages active ou non le marqueur des points à l'image des profils de consommation.

# %%
def tensorboardProjection(name_model,x, x_hat, x_encoded, x_conso, calendar_info, log_dir_projector, includeConsumptionProfileImages=True):
    #can take a bit longer to create and load in tensorboard projector, but it looks better in the projector
    if includeConsumptionProfileImages:
        nPoints=1500 #if you want to visualize images of consumption profiles and its recontruction in tensorboard, there is a maximum size that can be handle for a sprite image. 1830 is  
        x_encoded_reduced=x_encoded[0:nPoints,]
        images=createLoadProfileImages(x,x_hat,nPoints)
    else:
        nPoints=df_conso.shape[0]
        
    if includeConsumptionProfileImages:
        sprites=images_to_sprite(images)
        cv2.imwrite(os.path.join(log_dir_projector, 'sprite_4_classes.png'), sprites)
    
    writeMetaData(log_dir_projector,x_conso,calendar_info,nPoints,has_Odd=False)
    if includeConsumptionProfileImages:
        buildProjector(x_encoded_reduced,images=images, log_dir=log_dir_projector)
    else:
        buildProjector(x_encoded,images=None, log_dir=log_dir_projector)
        
    print(log_dir_projector)

# %%
#Visualisation des courbes de charge en entrée et reconstruite par le modèle

def display_loads(x, x_hat,date,mae):
    fig = plt.figure(dpi=100,figsize=(5,5))
    #set(gca,'Color','k')
    plt.plot(scaler_conso.inverse_transform(x), label = 'truth')
    plt.plot(scaler_conso.inverse_transform(x_hat), '--', label = 'reconstruction')
    plt.title(date+' - mean absolute error %0.2f GW' %(mae*std_sc/1000))
    plt.xlabel('hours')
    plt.ylabel('load (MW)')
    plt.xlim((0,48))
    plt.xticks([5,11,17,23,29,35,41], [3,6,9,12,15,18,21])
    plt.legend(loc='lower right')
    plt.grid();

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     <font size="+2"> <b> 1. Construction des différents modèles. </b> </font> <hr>
# </div>
#
#
# ### Rappels
#
# Les autoencodeurs variationnels sont des modèles qui fonctionnent en duo:
# - un encodeur qui traduit les données d'entrée dans un espace latent de dimension arbitrairement choisie. Plus exactement il cherche les paramètres de distribution des variables latentes dans chacune des dimensions.
# - un decodeur qui cherche à reconstruire les entrées à partir des coordonnées dans l'espace latent
#
# Pendant l'appentissage, le lien entre encodeur et decodeur est réalisé par l'échantilonnage selon les paramètres de distribution appris : chaque échantillon a des coordonnées latentes tirées aléatoirement selon cette dernière, que le décodeur cherche à retraduire dans l'espace de dimension initial.

# %% [markdown]
# ### Constructions des modèles
#
# Il s'agit dans un premier temps de paramétrer les dimensions des couches de nos réseaux de neurones:
# - celles de l'encodeur: **e_dim**
# - celles du décodeur: **d_dims**
# - les dimensions de notre espace latent: **z_dim** (chaque paramètre de distribution sera donc aussi de dimension z_dim)
# - les dimensions de notre embedding des conditions dans le cas dans CVAE

# %%
# paramètres de l'autoencodeur
z_dim = 4 # le nombre de dimensions voulues dans notre représentation latente
e_dims=[48,48,24,12]# les couches cachées du bloc encodeur; premier nombre = inputs_dim
d_dims=[48,24,12]# les couches cachées du bloc decodeur; premier nombre = outputs_dim
lr=3e-4 # le learning rate de l'optimiseur
input_dim = df_conso.shape[1]

# %% [markdown]
# Pour les paramètres liés au modèle, il faut rappeler le fonctionnement du VAE. On cherche la maximisation de la borne inférieure de la log-vraissemblance du modèle reconstruit ou ELBO qui se décompose en deux termes :
#
# ELBO $= \mathbb{E}_{q_\phi(z|x)} \log(p_\theta(x|z)) - KL(q_\phi(z|x) \| p(z))$
#
# Dans notre objectif d'apprentissage, cela est traduit par une perte à minimiser de la forme:
#
# Obj $= \|x - \hat{x}\| +  KL(q_\phi(z|x) \| p(z))$.
#
# - L'erreur de reconstruction peut être choisie selon une mesure en norme L1 ou L2. La norme L1 permet notamment d'obtenir des profils avec moins de valeurs abérrantes.
#
# - Un prior $p(z)$ laplacien plutôt que gaussien permet des concentrations plus piquées des groupements similaires, et renvoie plus loin les points atypiques.
#
# - Par ailleurs, pour faciliter l'apprentissage du modèle de façon structurée dans les dimensions choisies de l'espace latent, l'action peut se porter sur le choix du prior comme sur des critères de régularisation devant le terme de divergence.
#
#     Ces termes de régularisation s'appliquent de la façon suivante :
#
#     Obj $= \|x - \hat{x}\| +  \beta KL(q_\phi(z|x) \| p(z)) + \gamma MMD(q_\phi(z) \| p(z))$ si modèle InfoVAE
#     avec $\beta \in \left[0,1\right] $ et $\gamma \ge 0$ (si possible grand)

# %%
# paramètres de l'entrainement du modèle
epochs = 800
batch_size = 16

# %% [markdown]
# On va mettre en forme ici les facteurs sur lesquels on va rendre la représentation latente agnostique. Attention à normaliser les variables quantitatives et à one-hot encoder les variables catégorielles.

# %%
#on va conditionner sur les profils de température et le mois
calendar_cond = []
condtovae_dims = []
condarray=[]

df_temp, _ = apply_scaler(df_data, column="prevision_temp", df_chronic=df_temp,
                                      reference_window=None)

condarray.append(df_temp.values)
condtovae_dims.append(condarray[-1].shape[1])

for cc in calendar_cond:
    condarray.append(pd.get_dummies(df_calendar[cc], prefix=cc).values)
    condtovae_dims.append(condarray[-1].shape[1])

# %%
# définition des hyperparamètres 
embedding_dims = {0: [[48,8],4], 
              1: [[48, 8], 6],
              2: [[48, 12], 6],
              3: [[48, 10], 4],
              4: [[48, 8], 3],
              5: [[48,8], 2],
              6: [[48, 16, 8], 2]}


seeds = {idx: x for idx, x in enumerate(np.random.choice(np.arange(10000),5))}


models_name = [['CVAE_beta0.3_gamma250_'+str(embedding_dims[i])+'_seed'+str(seeds[j]) for j in range(len(seeds))] for i in range(len(embedding_dims))]

train_set = df_calendar.year.values <= 2018
test_set = df_calendar.year.values == 2019

input_cvae = [df_conso.values[train_set,:]] + [c[train_set,:] for c in condarray]
output_cvae = df_conso.values[train_set,:]

models = {}

# %%
from tensorflow.keras.callbacks import EarlyStopping
from datetime import datetime


for i in range(len(embedding_dims)):
    for j in range(len(seeds)):
        name_model = models_name[i][j]
        start_time = datetime.now()
        seed = seeds[j]
        beta = 0.3
        gamma = 250

        # Set different seed
        np.random.seed(seed)
        print(f"The random seed has been set to {seed}")

        print(f"---------- Parameters init with beta={beta} and gamma={gamma} ----------")
        vae_params = VAE_params(name=name_model, out_dir = log_dir_model)
        vae_params.set_model_params()
        vae_params.set_training_params()
        vae_params.model_params.encoder_dims = e_dims
        vae_params.model_params.decoder_dims = d_dims
        vae_params.model_params.cond_dims = condtovae_dims
        vae_params.model_params.with_embedding = True
        vae_params.model_params.emb_dims = embedding_dims[i]
        vae_params.model_params.kernel_initializer = 'glorot_uniform'
        vae_params.model_params.bias_initializer = 'glorot_uniform'
        
            
        loss_weights = {"recon_loss" : 3,"kl_loss" : beta, "info_loss" : gamma}
        vae_loss = VAELoss(loss_weights = loss_weights, custom_loss=None)
        vae_loss.options["log_prior_sigma"] = [-2.,-1.,0.,1]
        vae_params.training_params.loss = vae_loss
        vae_params.training_params.lr = 3e-4
        

        models[name_model]=CVAE(vae_params)
        models[name_model].build_model(vae_params)
        
        earl_stop = EarlyStopping(
            monitor='val_loss', min_delta=0, patience=100, verbose=0, mode='auto',
            baseline=None, restore_best_weights=True
        )
        print(f"---------- Model training ----------")
        models[name_model].train(input_cvae, output_cvae, epochs= epochs, verbose=0,
                batch_size=batch_size, callbacks=[earl_stop])

        end_time = datetime.now()
        print('Training duration: {}'.format(end_time - start_time))
# Out:
# The random seed has been set to 5825
# ---------- Parameters init with beta=0.3 and gamma=250 ----------
# Default values for model architecture are:
# with_embedding  :=  False
# with_Time2Vec  :=  False
# emb_dims  :=  []
# kernel_initializer  :=  glorot_uniform
# bias_initializer  :=  glorot_uniform
# reparametrize  :=  GaussianSampling
# intel_function  :=  scalar_binary
# input_dims  :=  48
# output_dims  :=  48
# t2v_dims  :=  12
# latent_dims  :=  4
# nb_latent_components  :=  2
# nb_encoder_ensemble  :=  1
# encoder_dims  :=  [12, 10, 8, 6]
# encoder_type  :=  NNBlockCond_model
# nb_decoder_outputs  :=  1
# nb_decoder_ensemble  :=  1
# decoder_dims  :=  [6, 12, 24, 48]
# latent_encoder_dims  :=  [4, 3, 3, 4]
# latent_mask  :=  0
# decoder_type  :=  InceptionBlock_model
# embedding_type  :=  EmbeddingBlock_model
# cond_dims  :=  []
# cond_insert  :=  {'encoder': [], 'decoder': []}
# context_dims  :=  None
# leapae_dims  :=  [4, None]
# Default parameters for training are a L2 loss with Adam optimizer with a learning rate of 0.0003
# Model: "cvae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  x_inputs (InputLayer)          [(None, 48)]         0           []
#
#  cond_inputs_0 (InputLayer)     [(None, 48)]         0           []
#
#  encoder (Functional)           [(None, 4),          9624        ['x_inputs[0][0]',
#                                  (None, 4)]                       'cond_inputs_0[0][0]']
#
#  reparametrizing_layer (Lambda)  (None, 4)           0           ['encoder[0][0]',
#                                                                   'encoder[0][1]']
#
#  decoder (Functional)           (None, 48)           10016       ['reparametrizing_layer[0][0]',
#                                                                   'cond_inputs_0[0][0]']
#
# ==================================================================================================
# Total params: 16,860
# Trainable params: 16,860
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "cond_emb"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  emb_input_cond_0 (InputLaye  [(None, 48)]             0
#  r)
#
#  cond_embcond_0 (Functional)  (None, 8)                2744
#
#  cond_emb_emb_concat (Concat  (None, 8)                0
#  enate)
#
#  cond_emb_last_reduction (De  (None, 4)                36
#  nse)
#
#  activation (Activation)     (None, 4)                 0
#
# =================================================================
# Total params: 2,780
# Trainable params: 2,780
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  enc_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  enc_inputs (InputLayer)        [(None, 48)]         0           []
#
#  cond_emb (Functional)          (None, 4)            2780        ['enc_cond_inputs_0[0][0]']
#
#  encoder_block_0 (Functional)   (None, 16)           6708        ['enc_inputs[0][0]',
#                                                                   'cond_emb[0][0]']
#
#  latent_dense_0_1 (Dense)       (None, 4)            68          ['encoder_block_0[0][0]']
#
#  latent_dense_0_2 (Dense)       (None, 4)            68          ['encoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 9,624
# Trainable params: 9,624
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dec_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  encoded_inputs (InputLayer)    [(None, 4)]          0           []
#
#  cond_emb (Functional)          (None, 4)            2780        ['dec_cond_inputs_0[0][0]']
#
#  decoder_block_0 (Functional)   (None, 92)           2772        ['encoded_inputs[0][0]',
#                                                                   'cond_emb[1][0]']
#
#  dec_output_0_1 (Dense)         (None, 48)           4464        ['decoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 10,016
# Trainable params: 10,016
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Losses and associated weight involved in the model:
# recon_loss  :  3
# kl_loss  :  0.3
# info_loss  :  250
# ---------- Model training ----------
# ## START TRAINING ##
# ## END TRAINING ##
# ## MODEL SAVED ##
# Training duration: 0:01:29.913420
# The random seed has been set to 6122
# ---------- Parameters init with beta=0.3 and gamma=250 ----------
# Default values for model architecture are:
# with_embedding  :=  False
# with_Time2Vec  :=  False
# emb_dims  :=  []
# kernel_initializer  :=  glorot_uniform
# bias_initializer  :=  glorot_uniform
# reparametrize  :=  GaussianSampling
# intel_function  :=  scalar_binary
# input_dims  :=  48
# output_dims  :=  48
# t2v_dims  :=  12
# latent_dims  :=  4
# nb_latent_components  :=  2
# nb_encoder_ensemble  :=  1
# encoder_dims  :=  [12, 10, 8, 6]
# encoder_type  :=  NNBlockCond_model
# nb_decoder_outputs  :=  1
# nb_decoder_ensemble  :=  1
# decoder_dims  :=  [6, 12, 24, 48]
# latent_encoder_dims  :=  [4, 3, 3, 4]
# latent_mask  :=  0
# decoder_type  :=  InceptionBlock_model
# embedding_type  :=  EmbeddingBlock_model
# cond_dims  :=  []
# cond_insert  :=  {'encoder': [], 'decoder': []}
# context_dims  :=  None
# leapae_dims  :=  [4, None]
# Default parameters for training are a L2 loss with Adam optimizer with a learning rate of 0.0003
# Model: "cvae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  x_inputs (InputLayer)          [(None, 48)]         0           []
#
#  cond_inputs_0 (InputLayer)     [(None, 48)]         0           []
#
#  encoder (Functional)           [(None, 4),          9624        ['x_inputs[0][0]',
#                                  (None, 4)]                       'cond_inputs_0[0][0]']
#
#  reparametrizing_layer (Lambda)  (None, 4)           0           ['encoder[0][0]',
#                                                                   'encoder[0][1]']
#
#  decoder (Functional)           (None, 48)           10016       ['reparametrizing_layer[0][0]',
#                                                                   'cond_inputs_0[0][0]']
#
# ==================================================================================================
# Total params: 16,860
# Trainable params: 16,860
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "cond_emb"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  emb_input_cond_0 (InputLaye  [(None, 48)]             0
#  r)
#
#  cond_embcond_0 (Functional)  (None, 8)                2744
#
#  cond_emb_emb_concat (Concat  (None, 8)                0
#  enate)
#
#  cond_emb_last_reduction (De  (None, 4)                36
#  nse)
#
#  activation_1 (Activation)   (None, 4)                 0
#
# =================================================================
# Total params: 2,780
# Trainable params: 2,780
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  enc_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  enc_inputs (InputLayer)        [(None, 48)]         0           []
#
#  cond_emb (Functional)          (None, 4)            2780        ['enc_cond_inputs_0[0][0]']
#
#  encoder_block_0 (Functional)   (None, 16)           6708        ['enc_inputs[0][0]',
#                                                                   'cond_emb[0][0]']
#
#  latent_dense_0_1 (Dense)       (None, 4)            68          ['encoder_block_0[0][0]']
#
#  latent_dense_0_2 (Dense)       (None, 4)            68          ['encoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 9,624
# Trainable params: 9,624
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dec_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  encoded_inputs (InputLayer)    [(None, 4)]          0           []
#
#  cond_emb (Functional)          (None, 4)            2780        ['dec_cond_inputs_0[0][0]']
#
#  decoder_block_0 (Functional)   (None, 92)           2772        ['encoded_inputs[0][0]',
#                                                                   'cond_emb[1][0]']
#
#  dec_output_0_1 (Dense)         (None, 48)           4464        ['decoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 10,016
# Trainable params: 10,016
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Losses and associated weight involved in the model:
# recon_loss  :  3
# kl_loss  :  0.3
# info_loss  :  250
# ---------- Model training ----------
# ## START TRAINING ##
# ## END TRAINING ##
# ## MODEL SAVED ##
# Training duration: 0:01:23.612263
# The random seed has been set to 4711
# ---------- Parameters init with beta=0.3 and gamma=250 ----------
# Default values for model architecture are:
# with_embedding  :=  False
# with_Time2Vec  :=  False
# emb_dims  :=  []
# kernel_initializer  :=  glorot_uniform
# bias_initializer  :=  glorot_uniform
# reparametrize  :=  GaussianSampling
# intel_function  :=  scalar_binary
# input_dims  :=  48
# output_dims  :=  48
# t2v_dims  :=  12
# latent_dims  :=  4
# nb_latent_components  :=  2
# nb_encoder_ensemble  :=  1
# encoder_dims  :=  [12, 10, 8, 6]
# encoder_type  :=  NNBlockCond_model
# nb_decoder_outputs  :=  1
# nb_decoder_ensemble  :=  1
# decoder_dims  :=  [6, 12, 24, 48]
# latent_encoder_dims  :=  [4, 3, 3, 4]
# latent_mask  :=  0
# decoder_type  :=  InceptionBlock_model
# embedding_type  :=  EmbeddingBlock_model
# cond_dims  :=  []
# cond_insert  :=  {'encoder': [], 'decoder': []}
# context_dims  :=  None
# leapae_dims  :=  [4, None]
# Default parameters for training are a L2 loss with Adam optimizer with a learning rate of 0.0003
# Model: "cvae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  x_inputs (InputLayer)          [(None, 48)]         0           []
#
#  cond_inputs_0 (InputLayer)     [(None, 48)]         0           []
#
#  encoder (Functional)           [(None, 4),          9624        ['x_inputs[0][0]',
#                                  (None, 4)]                       'cond_inputs_0[0][0]']
#
#  reparametrizing_layer (Lambda)  (None, 4)           0           ['encoder[0][0]',
#                                                                   'encoder[0][1]']
#
#  decoder (Functional)           (None, 48)           10016       ['reparametrizing_layer[0][0]',
#                                                                   'cond_inputs_0[0][0]']
#
# ==================================================================================================
# Total params: 16,860
# Trainable params: 16,860
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "cond_emb"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  emb_input_cond_0 (InputLaye  [(None, 48)]             0
#  r)
#
#  cond_embcond_0 (Functional)  (None, 8)                2744
#
#  cond_emb_emb_concat (Concat  (None, 8)                0
#  enate)
#
#  cond_emb_last_reduction (De  (None, 4)                36
#  nse)
#
#  activation_2 (Activation)   (None, 4)                 0
#
# =================================================================
# Total params: 2,780
# Trainable params: 2,780
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  enc_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  enc_inputs (InputLayer)        [(None, 48)]         0           []
#
#  cond_emb (Functional)          (None, 4)            2780        ['enc_cond_inputs_0[0][0]']
#
#  encoder_block_0 (Functional)   (None, 16)           6708        ['enc_inputs[0][0]',
#                                                                   'cond_emb[0][0]']
#
#  latent_dense_0_1 (Dense)       (None, 4)            68          ['encoder_block_0[0][0]']
#
#  latent_dense_0_2 (Dense)       (None, 4)            68          ['encoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 9,624
# Trainable params: 9,624
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dec_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  encoded_inputs (InputLayer)    [(None, 4)]          0           []
#
#  cond_emb (Functional)          (None, 4)            2780        ['dec_cond_inputs_0[0][0]']
#
#  decoder_block_0 (Functional)   (None, 92)           2772        ['encoded_inputs[0][0]',
#                                                                   'cond_emb[1][0]']
#
#  dec_output_0_1 (Dense)         (None, 48)           4464        ['decoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 10,016
# Trainable params: 10,016
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Losses and associated weight involved in the model:
# recon_loss  :  3
# kl_loss  :  0.3
# info_loss  :  250
# ---------- Model training ----------
# ## START TRAINING ##
# ## END TRAINING ##
# ## MODEL SAVED ##
# Training duration: 0:01:20.057195
# The random seed has been set to 1574
# ---------- Parameters init with beta=0.3 and gamma=250 ----------
# Default values for model architecture are:
# with_embedding  :=  False
# with_Time2Vec  :=  False
# emb_dims  :=  []
# kernel_initializer  :=  glorot_uniform
# bias_initializer  :=  glorot_uniform
# reparametrize  :=  GaussianSampling
# intel_function  :=  scalar_binary
# input_dims  :=  48
# output_dims  :=  48
# t2v_dims  :=  12
# latent_dims  :=  4
# nb_latent_components  :=  2
# nb_encoder_ensemble  :=  1
# encoder_dims  :=  [12, 10, 8, 6]
# encoder_type  :=  NNBlockCond_model
# nb_decoder_outputs  :=  1
# nb_decoder_ensemble  :=  1
# decoder_dims  :=  [6, 12, 24, 48]
# latent_encoder_dims  :=  [4, 3, 3, 4]
# latent_mask  :=  0
# decoder_type  :=  InceptionBlock_model
# embedding_type  :=  EmbeddingBlock_model
# cond_dims  :=  []
# cond_insert  :=  {'encoder': [], 'decoder': []}
# context_dims  :=  None
# leapae_dims  :=  [4, None]
# Default parameters for training are a L2 loss with Adam optimizer with a learning rate of 0.0003
# Model: "cvae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  x_inputs (InputLayer)          [(None, 48)]         0           []
#
#  cond_inputs_0 (InputLayer)     [(None, 48)]         0           []
#
#  encoder (Functional)           [(None, 4),          9624        ['x_inputs[0][0]',
#                                  (None, 4)]                       'cond_inputs_0[0][0]']
#
#  reparametrizing_layer (Lambda)  (None, 4)           0           ['encoder[0][0]',
#                                                                   'encoder[0][1]']
#
#  decoder (Functional)           (None, 48)           10016       ['reparametrizing_layer[0][0]',
#                                                                   'cond_inputs_0[0][0]']
#
# ==================================================================================================
# Total params: 16,860
# Trainable params: 16,860
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "cond_emb"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  emb_input_cond_0 (InputLaye  [(None, 48)]             0
#  r)
#
#  cond_embcond_0 (Functional)  (None, 8)                2744
#
#  cond_emb_emb_concat (Concat  (None, 8)                0
#  enate)
#
#  cond_emb_last_reduction (De  (None, 4)                36
#  nse)
#
#  activation_3 (Activation)   (None, 4)                 0
#
# =================================================================
# Total params: 2,780
# Trainable params: 2,780
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  enc_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  enc_inputs (InputLayer)        [(None, 48)]         0           []
#
#  cond_emb (Functional)          (None, 4)            2780        ['enc_cond_inputs_0[0][0]']
#
#  encoder_block_0 (Functional)   (None, 16)           6708        ['enc_inputs[0][0]',
#                                                                   'cond_emb[0][0]']
#
#  latent_dense_0_1 (Dense)       (None, 4)            68          ['encoder_block_0[0][0]']
#
#  latent_dense_0_2 (Dense)       (None, 4)            68          ['encoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 9,624
# Trainable params: 9,624
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dec_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  encoded_inputs (InputLayer)    [(None, 4)]          0           []
#
#  cond_emb (Functional)          (None, 4)            2780        ['dec_cond_inputs_0[0][0]']
#
#  decoder_block_0 (Functional)   (None, 92)           2772        ['encoded_inputs[0][0]',
#                                                                   'cond_emb[1][0]']
#
#  dec_output_0_1 (Dense)         (None, 48)           4464        ['decoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 10,016
# Trainable params: 10,016
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Losses and associated weight involved in the model:
# recon_loss  :  3
# kl_loss  :  0.3
# info_loss  :  250
# ---------- Model training ----------
# ## START TRAINING ##
# ## END TRAINING ##
# ## MODEL SAVED ##
# Training duration: 0:01:40.025540
# The random seed has been set to 3616
# ---------- Parameters init with beta=0.3 and gamma=250 ----------
# Default values for model architecture are:
# with_embedding  :=  False
# with_Time2Vec  :=  False
# emb_dims  :=  []
# kernel_initializer  :=  glorot_uniform
# bias_initializer  :=  glorot_uniform
# reparametrize  :=  GaussianSampling
# intel_function  :=  scalar_binary
# input_dims  :=  48
# output_dims  :=  48
# t2v_dims  :=  12
# latent_dims  :=  4
# nb_latent_components  :=  2
# nb_encoder_ensemble  :=  1
# encoder_dims  :=  [12, 10, 8, 6]
# encoder_type  :=  NNBlockCond_model
# nb_decoder_outputs  :=  1
# nb_decoder_ensemble  :=  1
# decoder_dims  :=  [6, 12, 24, 48]
# latent_encoder_dims  :=  [4, 3, 3, 4]
# latent_mask  :=  0
# decoder_type  :=  InceptionBlock_model
# embedding_type  :=  EmbeddingBlock_model
# cond_dims  :=  []
# cond_insert  :=  {'encoder': [], 'decoder': []}
# context_dims  :=  None
# leapae_dims  :=  [4, None]
# Default parameters for training are a L2 loss with Adam optimizer with a learning rate of 0.0003
# Model: "cvae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  x_inputs (InputLayer)          [(None, 48)]         0           []
#
#  cond_inputs_0 (InputLayer)     [(None, 48)]         0           []
#
#  encoder (Functional)           [(None, 4),          9624        ['x_inputs[0][0]',
#                                  (None, 4)]                       'cond_inputs_0[0][0]']
#
#  reparametrizing_layer (Lambda)  (None, 4)           0           ['encoder[0][0]',
#                                                                   'encoder[0][1]']
#
#  decoder (Functional)           (None, 48)           10016       ['reparametrizing_layer[0][0]',
#                                                                   'cond_inputs_0[0][0]']
#
# ==================================================================================================
# Total params: 16,860
# Trainable params: 16,860
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "cond_emb"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  emb_input_cond_0 (InputLaye  [(None, 48)]             0
#  r)
#
#  cond_embcond_0 (Functional)  (None, 8)                2744
#
#  cond_emb_emb_concat (Concat  (None, 8)                0
#  enate)
#
#  cond_emb_last_reduction (De  (None, 4)                36
#  nse)
#
#  activation_4 (Activation)   (None, 4)                 0
#
# =================================================================
# Total params: 2,780
# Trainable params: 2,780
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  enc_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  enc_inputs (InputLayer)        [(None, 48)]         0           []
#
#  cond_emb (Functional)          (None, 4)            2780        ['enc_cond_inputs_0[0][0]']
#
#  encoder_block_0 (Functional)   (None, 16)           6708        ['enc_inputs[0][0]',
#                                                                   'cond_emb[0][0]']
#
#  latent_dense_0_1 (Dense)       (None, 4)            68          ['encoder_block_0[0][0]']
#
#  latent_dense_0_2 (Dense)       (None, 4)            68          ['encoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 9,624
# Trainable params: 9,624
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dec_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  encoded_inputs (InputLayer)    [(None, 4)]          0           []
#
#  cond_emb (Functional)          (None, 4)            2780        ['dec_cond_inputs_0[0][0]']
#
#  decoder_block_0 (Functional)   (None, 92)           2772        ['encoded_inputs[0][0]',
#                                                                   'cond_emb[1][0]']
#
#  dec_output_0_1 (Dense)         (None, 48)           4464        ['decoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 10,016
# Trainable params: 10,016
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Losses and associated weight involved in the model:
# recon_loss  :  3
# kl_loss  :  0.3
# info_loss  :  250
# ---------- Model training ----------
# ## START TRAINING ##
# ## END TRAINING ##
# ## MODEL SAVED ##
# Training duration: 0:02:09.660252
# The random seed has been set to 5825
# ---------- Parameters init with beta=0.3 and gamma=250 ----------
# Default values for model architecture are:
# with_embedding  :=  False
# with_Time2Vec  :=  False
# emb_dims  :=  []
# kernel_initializer  :=  glorot_uniform
# bias_initializer  :=  glorot_uniform
# reparametrize  :=  GaussianSampling
# intel_function  :=  scalar_binary
# input_dims  :=  48
# output_dims  :=  48
# t2v_dims  :=  12
# latent_dims  :=  4
# nb_latent_components  :=  2
# nb_encoder_ensemble  :=  1
# encoder_dims  :=  [12, 10, 8, 6]
# encoder_type  :=  NNBlockCond_model
# nb_decoder_outputs  :=  1
# nb_decoder_ensemble  :=  1
# decoder_dims  :=  [6, 12, 24, 48]
# latent_encoder_dims  :=  [4, 3, 3, 4]
# latent_mask  :=  0
# decoder_type  :=  InceptionBlock_model
# embedding_type  :=  EmbeddingBlock_model
# cond_dims  :=  []
# cond_insert  :=  {'encoder': [], 'decoder': []}
# context_dims  :=  None
# leapae_dims  :=  [4, None]
# Default parameters for training are a L2 loss with Adam optimizer with a learning rate of 0.0003
# Model: "cvae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  x_inputs (InputLayer)          [(None, 48)]         0           []
#
#  cond_inputs_0 (InputLayer)     [(None, 48)]         0           []
#
#  encoder (Functional)           [(None, 4),          9922        ['x_inputs[0][0]',
#                                  (None, 4)]                       'cond_inputs_0[0][0]']
#
#  reparametrizing_layer (Lambda)  (None, 4)           0           ['encoder[0][0]',
#                                                                   'encoder[0][1]']
#
#  decoder (Functional)           (None, 48)           10298       ['reparametrizing_layer[0][0]',
#                                                                   'cond_inputs_0[0][0]']
#
# ==================================================================================================
# Total params: 17,422
# Trainable params: 17,422
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "cond_emb"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  emb_input_cond_0 (InputLaye  [(None, 48)]             0
#  r)
#
#  cond_embcond_0 (Functional)  (None, 8)                2744
#
#  cond_emb_emb_concat (Concat  (None, 8)                0
#  enate)
#
#  cond_emb_last_reduction (De  (None, 6)                54
#  nse)
#
#  activation_5 (Activation)   (None, 6)                 0
#
# =================================================================
# Total params: 2,798
# Trainable params: 2,798
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  enc_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  enc_inputs (InputLayer)        [(None, 48)]         0           []
#
#  cond_emb (Functional)          (None, 6)            2798        ['enc_cond_inputs_0[0][0]']
#
#  encoder_block_0 (Functional)   (None, 18)           6972        ['enc_inputs[0][0]',
#                                                                   'cond_emb[0][0]']
#
#  latent_dense_0_1 (Dense)       (None, 4)            76          ['encoder_block_0[0][0]']
#
#  latent_dense_0_2 (Dense)       (None, 4)            76          ['encoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 9,922
# Trainable params: 9,922
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dec_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  encoded_inputs (InputLayer)    [(None, 4)]          0           []
#
#  cond_emb (Functional)          (None, 6)            2798        ['dec_cond_inputs_0[0][0]']
#
#  decoder_block_0 (Functional)   (None, 94)           2940        ['encoded_inputs[0][0]',
#                                                                   'cond_emb[1][0]']
#
#  dec_output_0_1 (Dense)         (None, 48)           4560        ['decoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 10,298
# Trainable params: 10,298
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Losses and associated weight involved in the model:
# recon_loss  :  3
# kl_loss  :  0.3
# info_loss  :  250
# ---------- Model training ----------
# ## START TRAINING ##
# ## END TRAINING ##
# ## MODEL SAVED ##
# Training duration: 0:02:13.024647
# The random seed has been set to 6122
# ---------- Parameters init with beta=0.3 and gamma=250 ----------
# Default values for model architecture are:
# with_embedding  :=  False
# with_Time2Vec  :=  False
# emb_dims  :=  []
# kernel_initializer  :=  glorot_uniform
# bias_initializer  :=  glorot_uniform
# reparametrize  :=  GaussianSampling
# intel_function  :=  scalar_binary
# input_dims  :=  48
# output_dims  :=  48
# t2v_dims  :=  12
# latent_dims  :=  4
# nb_latent_components  :=  2
# nb_encoder_ensemble  :=  1
# encoder_dims  :=  [12, 10, 8, 6]
# ...
# recon_loss  :  3
# kl_loss  :  0.3
# info_loss  :  250
# ---------- Model training ----------
# ## START TRAINING ##
# ## END TRAINING ##
# ## MODEL SAVED ##
# Training duration: 0:02:13.686658
# The random seed has been set to 1574
# ---------- Parameters init with beta=0.3 and gamma=250 ----------
# Default values for model architecture are:
# with_embedding  :=  False
# with_Time2Vec  :=  False
# emb_dims  :=  []
# kernel_initializer  :=  glorot_uniform
# bias_initializer  :=  glorot_uniform
# reparametrize  :=  GaussianSampling
# intel_function  :=  scalar_binary
# input_dims  :=  48
# output_dims  :=  48
# t2v_dims  :=  12
# latent_dims  :=  4
# nb_latent_components  :=  2
# nb_encoder_ensemble  :=  1
# encoder_dims  :=  [12, 10, 8, 6]
# encoder_type  :=  NNBlockCond_model
# nb_decoder_outputs  :=  1
# nb_decoder_ensemble  :=  1
# decoder_dims  :=  [6, 12, 24, 48]
# latent_encoder_dims  :=  [4, 3, 3, 4]
# latent_mask  :=  0
# decoder_type  :=  InceptionBlock_model
# embedding_type  :=  EmbeddingBlock_model
# cond_dims  :=  []
# cond_insert  :=  {'encoder': [], 'decoder': []}
# context_dims  :=  None
# leapae_dims  :=  [4, None]
# Default parameters for training are a L2 loss with Adam optimizer with a learning rate of 0.0003
# Model: "cvae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  x_inputs (InputLayer)          [(None, 48)]         0           []
#
#  cond_inputs_0 (InputLayer)     [(None, 48)]         0           []
#
#  encoder (Functional)           [(None, 4),          9854        ['x_inputs[0][0]',
#                                  (None, 4)]                       'cond_inputs_0[0][0]']
#
#  reparametrizing_layer (Lambda)  (None, 4)           0           ['encoder[0][0]',
#                                                                   'encoder[0][1]']
#
#  decoder (Functional)           (None, 48)           10262       ['reparametrizing_layer[0][0]',
#                                                                   'cond_inputs_0[0][0]']
#
# ==================================================================================================
# Total params: 16,826
# Trainable params: 16,826
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "cond_emb"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  emb_input_cond_0 (InputLaye  [(None, 48)]             0
#  r)
#
#  cond_embcond_0 (Functional)  (None, 8)                3272
#
#  cond_emb_emb_concat (Concat  (None, 8)                0
#  enate)
#
#  cond_emb_last_reduction (De  (None, 2)                18
#  nse)
#
#  activation_33 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 3,290
# Trainable params: 3,290
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  enc_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  enc_inputs (InputLayer)        [(None, 48)]         0           []
#
#  cond_emb (Functional)          (None, 2)            3290        ['enc_cond_inputs_0[0][0]']
#
#  encoder_block_0 (Functional)   (None, 14)           6444        ['enc_inputs[0][0]',
#                                                                   'cond_emb[0][0]']
#
#  latent_dense_0_1 (Dense)       (None, 4)            60          ['encoder_block_0[0][0]']
#
#  latent_dense_0_2 (Dense)       (None, 4)            60          ['encoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 9,854
# Trainable params: 9,854
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dec_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  encoded_inputs (InputLayer)    [(None, 4)]          0           []
#
#  cond_emb (Functional)          (None, 2)            3290        ['dec_cond_inputs_0[0][0]']
#
#  decoder_block_0 (Functional)   (None, 90)           2604        ['encoded_inputs[0][0]',
#                                                                   'cond_emb[1][0]']
#
#  dec_output_0_1 (Dense)         (None, 48)           4368        ['decoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 10,262
# Trainable params: 10,262
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Losses and associated weight involved in the model:
# recon_loss  :  3
# kl_loss  :  0.3
# info_loss  :  250
# ---------- Model training ----------
# ## START TRAINING ##
# ## END TRAINING ##
# ## MODEL SAVED ##
# Training duration: 0:02:01.421440
# The random seed has been set to 3616
# ---------- Parameters init with beta=0.3 and gamma=250 ----------
# Default values for model architecture are:
# with_embedding  :=  False
# with_Time2Vec  :=  False
# emb_dims  :=  []
# kernel_initializer  :=  glorot_uniform
# bias_initializer  :=  glorot_uniform
# reparametrize  :=  GaussianSampling
# intel_function  :=  scalar_binary
# input_dims  :=  48
# output_dims  :=  48
# t2v_dims  :=  12
# latent_dims  :=  4
# nb_latent_components  :=  2
# nb_encoder_ensemble  :=  1
# encoder_dims  :=  [12, 10, 8, 6]
# encoder_type  :=  NNBlockCond_model
# nb_decoder_outputs  :=  1
# nb_decoder_ensemble  :=  1
# decoder_dims  :=  [6, 12, 24, 48]
# latent_encoder_dims  :=  [4, 3, 3, 4]
# latent_mask  :=  0
# decoder_type  :=  InceptionBlock_model
# embedding_type  :=  EmbeddingBlock_model
# cond_dims  :=  []
# cond_insert  :=  {'encoder': [], 'decoder': []}
# context_dims  :=  None
# leapae_dims  :=  [4, None]
# Default parameters for training are a L2 loss with Adam optimizer with a learning rate of 0.0003
# Model: "cvae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  x_inputs (InputLayer)          [(None, 48)]         0           []
#
#  cond_inputs_0 (InputLayer)     [(None, 48)]         0           []
#
#  encoder (Functional)           [(None, 4),          9854        ['x_inputs[0][0]',
#                                  (None, 4)]                       'cond_inputs_0[0][0]']
#
#  reparametrizing_layer (Lambda)  (None, 4)           0           ['encoder[0][0]',
#                                                                   'encoder[0][1]']
#
#  decoder (Functional)           (None, 48)           10262       ['reparametrizing_layer[0][0]',
#                                                                   'cond_inputs_0[0][0]']
#
# ==================================================================================================
# Total params: 16,826
# Trainable params: 16,826
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "cond_emb"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  emb_input_cond_0 (InputLaye  [(None, 48)]             0
#  r)
#
#  cond_embcond_0 (Functional)  (None, 8)                3272
#
#  cond_emb_emb_concat (Concat  (None, 8)                0
#  enate)
#
#  cond_emb_last_reduction (De  (None, 2)                18
#  nse)
#
#  activation_34 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 3,290
# Trainable params: 3,290
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  enc_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  enc_inputs (InputLayer)        [(None, 48)]         0           []
#
#  cond_emb (Functional)          (None, 2)            3290        ['enc_cond_inputs_0[0][0]']
#
#  encoder_block_0 (Functional)   (None, 14)           6444        ['enc_inputs[0][0]',
#                                                                   'cond_emb[0][0]']
#
#  latent_dense_0_1 (Dense)       (None, 4)            60          ['encoder_block_0[0][0]']
#
#  latent_dense_0_2 (Dense)       (None, 4)            60          ['encoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 9,854
# Trainable params: 9,854
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dec_cond_inputs_0 (InputLayer)  [(None, 48)]        0           []
#
#  encoded_inputs (InputLayer)    [(None, 4)]          0           []
#
#  cond_emb (Functional)          (None, 2)            3290        ['dec_cond_inputs_0[0][0]']
#
#  decoder_block_0 (Functional)   (None, 90)           2604        ['encoded_inputs[0][0]',
#                                                                   'cond_emb[1][0]']
#
#  dec_output_0_1 (Dense)         (None, 48)           4368        ['decoder_block_0[0][0]']
#
# ==================================================================================================
# Total params: 10,262
# Trainable params: 10,262
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Losses and associated weight involved in the model:
# recon_loss  :  3
# kl_loss  :  0.3
# info_loss  :  250
# ---------- Model training ----------
# ## START TRAINING ##
# ## END TRAINING ##
# ## MODEL SAVED ##
# Training duration: 0:02:10.983795

# %%
models
# Out:
# {'CVAE_beta0.3_gamma250_[[48, 8], 4]_seed5825': <src.models.CVAE at 0x7fce84487640>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 4]_seed6122': <src.models.CVAE at 0x7fce6ed9cd60>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 4]_seed4711': <src.models.CVAE at 0x7fce6e9ed940>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 4]_seed1574': <src.models.CVAE at 0x7fce6e07cb50>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 4]_seed3616': <src.models.CVAE at 0x7fce6e9deb20>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 6]_seed5825': <src.models.CVAE at 0x7fce6da090d0>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 6]_seed6122': <src.models.CVAE at 0x7fce6d187190>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 6]_seed4711': <src.models.CVAE at 0x7fce6d51a2e0>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 6]_seed1574': <src.models.CVAE at 0x7fce6c7fe1f0>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 6]_seed3616': <src.models.CVAE at 0x7fce6e9c9c70>,
#  'CVAE_beta0.3_gamma250_[[48, 12], 6]_seed5825': <src.models.CVAE at 0x7fce6c394940>,
#  'CVAE_beta0.3_gamma250_[[48, 12], 6]_seed6122': <src.models.CVAE at 0x7fce62ebf1c0>,
#  'CVAE_beta0.3_gamma250_[[48, 12], 6]_seed4711': <src.models.CVAE at 0x7fce629bd130>,
#  'CVAE_beta0.3_gamma250_[[48, 12], 6]_seed1574': <src.models.CVAE at 0x7fce621a11f0>,
#  'CVAE_beta0.3_gamma250_[[48, 12], 6]_seed3616': <src.models.CVAE at 0x7fce6c4a73a0>,
#  'CVAE_beta0.3_gamma250_[[48, 10], 4]_seed5825': <src.models.CVAE at 0x7fce604008e0>,
#  'CVAE_beta0.3_gamma250_[[48, 10], 4]_seed6122': <src.models.CVAE at 0x7fce2bfb6ac0>,
#  'CVAE_beta0.3_gamma250_[[48, 10], 4]_seed4711': <src.models.CVAE at 0x7fce2b9eea90>,
#  'CVAE_beta0.3_gamma250_[[48, 10], 4]_seed1574': <src.models.CVAE at 0x7fce28345c70>,
#  'CVAE_beta0.3_gamma250_[[48, 10], 4]_seed3616': <src.models.CVAE at 0x7fce602e6d90>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 3]_seed5825': <src.models.CVAE at 0x7fce0f74df10>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 3]_seed6122': <src.models.CVAE at 0x7fce2bf42ca0>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 3]_seed4711': <src.models.CVAE at 0x7fce0cff0ee0>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 3]_seed1574': <src.models.CVAE at 0x7fce0c997f10>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 3]_seed3616': <src.models.CVAE at 0x7fcdef784b20>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 2]_seed5825': <src.models.CVAE at 0x7fce2be5de20>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 2]_seed6122': <src.models.CVAE at 0x7fcdef4e59d0>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 2]_seed4711': <src.models.CVAE at 0x7fcdee7aff70>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 2]_seed1574': <src.models.CVAE at 0x7fcdee22ca00>,
#  'CVAE_beta0.3_gamma250_[[48, 8], 2]_seed3616': <src.models.CVAE at 0x7fcdec06b3d0>,
#  'CVAE_beta0.3_gamma250_[[48, 16, 8], 2]_seed5825': <src.models.CVAE at 0x7fcde01c65b0>,
#  'CVAE_beta0.3_gamma250_[[48, 16, 8], 2]_seed6122': <src.models.CVAE at 0x7fcdc44e0040>,
#  'CVAE_beta0.3_gamma250_[[48, 16, 8], 2]_seed4711': <src.models.CVAE at 0x7fcde02ad7c0>,
#  'CVAE_beta0.3_gamma250_[[48, 16, 8], 2]_seed1574': <src.models.CVAE at 0x7fcdc7a11610>,
#  'CVAE_beta0.3_gamma250_[[48, 16, 8], 2]_seed3616': <src.models.CVAE at 0x7fcdc41a2910>}

# %%
data_encoded = [[models[models_name[i][j]].encoder.predict(input_cvae) for j in range(len(seeds))] for i in range(len(embedding_dims))]
data_encoded = np.array(data_encoded)

# %%
udr_scores_model = {}
scores = compute_udr_score(data_encoded=data_encoded, P=3, filter_low_kl=False, include_raw_correlations=True)

# %%
id_temp = np.argmax(np.array(list(factorDesc.keys()))=='temperature')
id_temp
# Out:
# 4

# %%
display_udr_scores(data_encoded, scores['model_scores'], models_name,
                                                         factorMatrix[train_set,id_temp].reshape(-1,1),
                                                         {'temperature':'regressor'},
                                                         embedding_dims,
                                                         palette='Greens')
# Out:
#                                                                                                                                              - 100.00% - Model n°35/35
#         score           metric  hyperparam  seed
# 0         inf       DCI Disent           0  5825
# 1    0.473108  INFORMATIVENESS           0  5825
# 2    0.036391      COMPACTNESS           0  5825
# 3    0.002634              MIG           0  5825
# 4         NaN       MODULARITY           0  5825
# ..        ...              ...         ...   ...
# 170       inf       DCI Disent           6  3616
# 171  0.375660  INFORMATIVENESS           6  3616
# 172  0.011269      COMPACTNESS           6  3616
# 173  0.002256              MIG           6  3616
# 174       NaN       MODULARITY           6  3616
#
# [175 rows x 4 columns]

# %%
embedding_dims
# Out:
# {0: [[48, 8], 4],
#  1: [[48, 8], 6],
#  2: [[48, 12], 6],
#  3: [[48, 10], 4],
#  4: [[48, 8], 3],
#  5: [[48, 8], 2],
#  6: [[48, 16, 8], 2]}

# %% [markdown]
# ## Evaluer l'importance et la qualité des embeggings appris

# %% [markdown]
# Nous allons voir:
# - l'importance portée par des variables dans la représentation latente
# - l'importance portée par des variables dans l'embedding conditionnel
#
# Nous nous appuyons pour cela sur des score d'information, de démêlement, de compacité et de modularité
#
# Nous devrions constater que des variables importante dans l'embedding conditionnel ne le sont plus dans la représentation latente: elles ont été factorisées

# %%
def see_metric(hyper, seed):
    # Allow to evaluate our models on a specific (hyperparameter, seed) couple. (with their indexes)
    x_encoded = data_encoded[hyper,seed,0]
    print(f"Model {models_name[hyper][seed]}")
    model_eval, importanceMatrix =evaluate_latent_code(x_encoded, factorMatrix[train_set,:], factorDesc, orthogonalize=True, normalize_information=True)
    display_evaluation_latent_code(model_eval, z_dim, factorDesc)
    prez_2D(data_encoded[hyper,seed,0], factorMatrix[train_set,:], temperatureMean[train_set,:])
    prez_2D_holidays(data_encoded[hyper,seed,0], factorMatrix[train_set,:], temperatureMean[train_set,:])

    cond_emb = models[models_name[hyper][seed]].cond_embedding.predict(input_cvae[1:])
    model_eval, importanceMatrix =evaluate_latent_code(cond_emb, factorMatrix[train_set,:], factorDesc, orthogonalize=True, normalize_information=True)
    #normalize_information normalise le score avec le minimum obtenu avec une projection aléatoire
    display_evaluation_latent_code(model_eval, cond_emb.shape[1], factorDesc)

# %%
see_metric(4,3)
# Out:
# Model CVAE_beta0.3_gamma250_[[48, 8], 3]_seed6075
